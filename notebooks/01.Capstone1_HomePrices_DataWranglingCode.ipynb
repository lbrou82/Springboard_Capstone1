# %% [markdown]
# <h2><center>Predicting Home Values in Los Angeles’ South Bay</center></h2>
# <h3><center>Springboard | Capstone 1:   Data Wrangling Code</center></h3>
# <h4><center>By: Lauren Broussard</center></h4>

# %%
#import necessary modules
import glob as glob
import pandas as pd
import os

# %% [markdown]
# #### IMPORT DATA AND MERGE TABLES

# %%
def concat_redfin(pathway, collection_num):
    '''Function to merge all csv files together into one dataframe
    and create additional columns to track data'''

    # get list of filenames and verify length
    filenames = glob.glob(pathway)
    print("# of Files in Collection {collection}: ".format(collection=collection_num),len(filenames))

    # create empty list to hold dataframes
    redfin_lst = []

    # create list of dataframes, redfin_lst
    for file in filenames:
        df = pd.read_csv(file)
        redfin_lst.append(df)

    # append filename and collection number to each dataframe,
    for dataframe, filename in zip(redfin_lst, filenames):
        dataframe['FILENAME'] = os.path.basename(filename)
        dataframe['COLLECTION'] = collection_num
        dataframe['SOLD DATE'] = pd.to_datetime(dataframe['SOLD DATE'], format='%B-%d-%Y')
        
    # stack dataframes together
    redfin = pd.concat(redfin_lst)

     
    return redfin

# %%
# run concat_redfin function on each collection of files, and assign collection number
redfin1 = concat_redfin('../data/raw/Redfin Files/Redfin-1/*.csv', '1')
redfin2 = concat_redfin('../data/raw/Redfin Files/Redfin-2/*.csv', '2')
# Out:
# # of Files in Collection 1:  53
# # of Files in Collection 2:  31

# %% [markdown]
# #### View initial information about the DataFrames

# %%
# print basic info about Collection #1 dataframe
print("Collection 1: Rows - {rows}; Columns - {columns}".format(rows=len(redfin1.index), \
                                                                columns=len(redfin1.columns)))
# Out:
# Collection 1: Rows - 11688; Columns - 29

# %%
# print basic info about Collection #2 dataframe
print("Collection 2: Rows - {rows}; Columns - {columns}".format(rows=len(redfin2.index), \
                                                                columns=len(redfin2.columns)))
# Out:
# Collection 2: Rows - 7839; Columns - 29

# %% [markdown]
# #### Final Merge

# %%
# merge collections 1 and 2 together and reset index for new dataframe
south_bay_orig = pd.concat([redfin1,redfin2]).reset_index(drop=True)

# %%
# drop 'URL column' and inspect new dataframe
south_bay_orig.drop('URL (SEE http://www.redfin.com/buy-a-home/comparative-market-analysis FOR INFO ON PRICING)'\
                    ,axis=1,inplace=True)
south_bay_orig.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19527 entries, 0 to 19526
# Data columns (total 28 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   SALE TYPE                   19527 non-null  object
#  1   SOLD DATE                   17133 non-null  datetime64[ns]
#  2   PROPERTY TYPE               19527 non-null  object
#  3   ADDRESS                     19509 non-null  object
#  4   CITY                        19519 non-null  object
#  5   STATE OR PROVINCE           19527 non-null  object
#  6   ZIP OR POSTAL CODE          19507 non-null  float64
#  7   PRICE                       19527 non-null  int64
#  8   BEDS                        19349 non-null  float64
#  9   BATHS                       19294 non-null  float64
#  10  LOCATION                    17113 non-null  object
#  11  SQUARE FEET                 19072 non-null  float64
#  12  LOT SIZE                    18219 non-null  float64
#  13  YEAR BUILT                  19355 non-null  float64
#  14  DAYS ON MARKET              17133 non-null  float64
#  15  $/SQUARE FEET               19069 non-null  float64
#  16  HOA/MONTH                   5454 non-null   float64
#  17  STATUS                      17133 non-null  object
#  18  NEXT OPEN HOUSE START TIME  0 non-null      float64
#  19  NEXT OPEN HOUSE END TIME    0 non-null      float64
#  20  SOURCE                      17133 non-null  object
#  21  MLS#                        17133 non-null  object
#  22  FAVORITE                    19527 non-null  object
#  23  INTERESTED                  19527 non-null  object
#  24  LATITUDE                    19527 non-null  float64
#  25  LONGITUDE                   19527 non-null  float64
#  26  FILENAME                    19527 non-null  object
#  27  COLLECTION                  19527 non-null  object
# dtypes: datetime64[ns](1), float64(13), int64(1), object(13)
# memory usage: 4.2+ MB

# %% [markdown]
# #### DROPPING COLUMNS
#
# Let's continue to inspect the data, and remove any additional unnecessary columns.

# %%
# Inspect Sale Type, Status columns
group_cols = south_bay_orig.groupby(['SALE TYPE', 'STATUS'])['SOLD DATE'].count()
print(group_cols)
# Out:
# SALE TYPE  STATUS
# PAST SALE  Sold      17133
# Name: SOLD DATE, dtype: int64

# %%
#create list of other columns to drop
cols_to_drop = ['SALE TYPE', 'NEXT OPEN HOUSE START TIME', 'NEXT OPEN HOUSE END TIME',\
                'STATUS','FAVORITE', 'INTERESTED', 'SOURCE']

# create new south_bay dataframe and drop columns
south_bay = south_bay_orig.drop(cols_to_drop, axis=1)

# %%
# verify remaining columns
print(south_bay.columns, len(south_bay.columns))
# Out:
# Index(['SOLD DATE', 'PROPERTY TYPE', 'ADDRESS', 'CITY', 'STATE OR PROVINCE',
#        'ZIP OR POSTAL CODE', 'PRICE', 'BEDS', 'BATHS', 'LOCATION',
#        'SQUARE FEET', 'LOT SIZE', 'YEAR BUILT', 'DAYS ON MARKET',
#        '$/SQUARE FEET', 'HOA/MONTH', 'MLS#', 'LATITUDE', 'LONGITUDE',
#        'FILENAME', 'COLLECTION'],
#       dtype='object') 21

# %% [markdown]
# #### LOOK FOR MISSING/INCORRECT VALUES (BY FEATURE)

# %% [markdown]
# SOLD DATE:

# %%
# remove rows with no sold date
south_bay.dropna(subset=['SOLD DATE'], axis=0, inplace=True)

# %%
# find min and max sold dates for each collection 
coll1 = south_bay['COLLECTION'] == '1'
coll2 = south_bay['COLLECTION'] == '2'

print("Collection 1: Min Date - ", south_bay[coll1]['SOLD DATE'].min(), \
      "Max Date - ", south_bay[coll1]['SOLD DATE'].max())
print("Collection 2: Min Date - ", south_bay[coll2]['SOLD DATE'].min(), "Max Date - ", \
      south_bay[coll2]['SOLD DATE'].max())
# Out:
# Collection 1: Min Date -  2018-01-22 00:00:00 Max Date -  2020-01-24 00:00:00
# Collection 2: Min Date -  2018-02-06 00:00:00 Max Date -  2020-02-07 00:00:00

# %%
# reduce dataframe to keep SOLD DATES from 2018-02-06 to 2020-01-24
south_bay = south_bay[(south_bay['SOLD DATE'] >= '2018-02-06') & (south_bay['SOLD DATE'] <= '2020-01-24')]

# %% [markdown]
# PROPERTY TYPE:

# %%
# look at values for property type column
group_type = south_bay.groupby(['PROPERTY TYPE'])['SOLD DATE'].count()
print(group_type)
# Out:
# PROPERTY TYPE
# Condo/Co-op                  2610
# Mobile/Manufactured Home      351
# Multi-Family (2-4 Unit)      1069
# Multi-Family (5+ Unit)        273
# Single Family Residential    9950
# Townhouse                    2606
# Vacant Land                    56
# Name: SOLD DATE, dtype: int64

# %%
# further inspect 'Condo/Co-op' 
south_bay[south_bay['PROPERTY TYPE'] == 'Condo/Co-op'].describe()
# Out:
#        ZIP OR POSTAL CODE         PRICE         BEDS        BATHS  \
# count         2610.000000  2.610000e+03  2610.000000  2610.000000
# mean         90420.400000  5.374654e+05     2.063218     1.893103
# std            198.762475  2.532352e+05     0.755856     0.624512
# min          90043.000000  1.830000e+05     0.000000     0.750000
# 25%          90275.000000  3.750000e+05     2.000000     1.500000
# 50%          90302.000000  4.692500e+05     2.000000     2.000000
# 75%          90505.000000  6.400000e+05     2.000000     2.000000
# max          90746.000000  3.599000e+06     5.000000     4.000000
#
#        SQUARE FEET      LOT SIZE   YEAR BUILT  DAYS ON MARKET  $/SQUARE FEET  \
# count  2610.000000  2.492000e+03  2608.000000     2610.000000    2610.000000
# mean   1147.473180  1.159523e+06  1981.980061      367.028352     477.033333
# std     380.734403  3.151084e+07    14.498535      206.966548     157.521229
# min     397.000000  4.000000e+00  1944.000000        2.000000     105.000000
# 25%     875.000000  2.472400e+04  1973.000000      189.000000     368.000000
# 50%    1098.000000  6.551050e+04  1980.000000      359.500000     441.000000
# 75%    1351.750000  1.769820e+05  1988.000000      554.000000     549.000000
# max    3150.000000  1.148808e+09  2019.000000      730.000000    1477.000000
#
#          HOA/MONTH     LATITUDE    LONGITUDE
# count  2573.000000  2610.000000  2610.000000
# mean    343.550719    33.849764  -118.345543
# std     121.119032     0.072976     0.048119
# min      10.000000    33.708504  -118.453205
# 25%     275.000000    33.798982  -118.380794
# 50%     338.000000    33.832205  -118.341884
# 75%     408.000000    33.900681  -118.302446
# max    2346.000000    33.980126  -118.246078

# %%
# further inspect 'Mobile/Manufactured Home' 
south_bay[south_bay['PROPERTY TYPE'] == 'Mobile/Manufactured Home'].describe()
# Out:
#        ZIP OR POSTAL CODE          PRICE        BEDS       BATHS  SQUARE FEET  \
# count          351.000000     351.000000  351.000000  351.000000   299.000000
# mean         90582.982906  135404.792023    2.136752    1.695157  1167.250836
# std            167.340576  108172.992290    0.644617    0.426805   381.750956
# min          90247.000000      25.000000    1.000000    1.000000   370.000000
# 25%          90502.000000   65250.000000    2.000000    1.250000   890.000000
# 50%          90710.000000  105000.000000    2.000000    2.000000  1160.000000
# 75%          90732.000000  180000.000000    3.000000    2.000000  1440.000000
# max          90748.000000  660000.000000    4.000000    2.750000  2311.000000
#
#            LOT SIZE   YEAR BUILT  DAYS ON MARKET  $/SQUARE FEET    HOA/MONTH  \
# count  4.000000e+01   344.000000      351.000000     299.000000    31.000000
# mean   4.867528e+05  1981.781977      366.763533     119.187291   685.387097
# std    8.588946e+05    16.269294      212.340665      88.758429   553.406763
# min    1.302000e+03  1955.000000        1.000000       0.000000     0.000000
# 25%    3.737500e+03  1971.000000      176.500000      65.500000   424.000000
# 50%    7.980150e+04  1975.000000      385.000000     101.000000   550.000000
# 75%    3.696890e+05  2000.000000      547.500000     144.000000   778.000000
# max    3.113589e+06  2018.000000      722.000000     688.000000  2697.000000
#
#          LATITUDE   LONGITUDE
# count  351.000000  351.000000
# mean    33.818503 -118.308520
# std      0.040502    0.031317
# min     33.723242 -118.396473
# 25%     33.799656 -118.329708
# 50%     33.809912 -118.306607
# 75%     33.859199 -118.294537
# max     33.916221 -118.242632

# %%
# further inspect 'Multi-Family (2-4 Unit)'
south_bay[south_bay['PROPERTY TYPE'] == 'Multi-Family (2-4 Unit)'].describe()
# Out:
#        ZIP OR POSTAL CODE         PRICE         BEDS        BATHS  \
# count         1069.000000  1.069000e+03  1065.000000  1010.000000
# mean         90330.855005  9.410304e+05     5.784038     3.833168
# std            256.994827  9.309306e+05     3.156675     2.177917
# min          90001.000000  5.100000e+04     0.000000     1.000000
# 25%          90059.000000  5.899000e+05     4.000000     2.000000
# 50%          90277.000000  7.350000e+05     5.000000     3.000000
# 75%          90502.000000  1.040000e+06     7.000000     4.000000
# max          90810.000000  2.425000e+07    40.000000    24.000000
#
#        SQUARE FEET       LOT SIZE   YEAR BUILT  DAYS ON MARKET  $/SQUARE FEET  \
# count  1016.000000    1069.000000  1068.000000     1069.000000    1016.000000
# mean   2447.697835    6536.525725  1952.057116      349.572498    2755.102362
# std    1020.367559    5438.739009    24.635440      209.666254   34756.900603
# min       1.000000    1345.000000  1895.000000        1.000000      35.000000
# 25%    1679.750000    5101.000000  1932.500000      167.000000     274.000000
# 50%    2173.500000    5888.000000  1952.000000      323.000000     334.000000
# 75%    3148.500000    7123.000000  1963.000000      544.000000     420.000000
# max    6039.000000  144956.000000  2019.000000      729.000000  635000.000000
#
#         HOA/MONTH     LATITUDE    LONGITUDE
# count    5.000000  1069.000000  1069.000000
# mean   503.200000    33.882303  -118.318409
# std    192.363458     0.080528     0.048224
# min    395.000000    33.709403  -118.452421
# 25%    396.000000    33.829304  -118.356675
# 50%    440.000000    33.898502  -118.307881
# 75%    440.000000    33.952489  -118.279133
# max    845.000000    33.987501  -118.214689

# %%
# further inspect 'Multi-Family (5+ Unit)' 
south_bay[south_bay['PROPERTY TYPE'] == 'Multi-Family (5+ Unit)'].describe()
# Out:
#        ZIP OR POSTAL CODE         PRICE        BEDS       BATHS   SQUARE FEET  \
# count          273.000000  2.730000e+02  269.000000  271.000000    273.000000
# mean         90350.095238  2.722932e+06   14.137546   15.274908   7662.974359
# std            196.194190  2.636131e+06    9.899855   49.988398   6866.522381
# min          90001.000000  3.000000e+05    0.000000    1.000000      3.000000
# 25%          90250.000000  1.275000e+06    8.000000    6.000000   4297.000000
# 50%          90301.000000  1.699000e+06   12.000000    8.000000   5918.000000
# 75%          90501.000000  3.200000e+06   16.000000   14.000000   8910.000000
# max          90745.000000  2.425000e+07   73.000000  784.000000  81243.000000
#
#            LOT SIZE   YEAR BUILT  DAYS ON MARKET  $/SQUARE FEET  HOA/MONTH  \
# count  2.730000e+02   272.000000      273.000000     273.000000        1.0
# mean   2.308953e+06  1960.672794      373.479853     978.150183      188.0
# std    2.679781e+07    19.540088      218.843620   10067.124792        NaN
# min    2.259000e+03  1912.000000        2.000000     106.000000      188.0
# 25%    6.802000e+03  1953.000000      159.000000     254.000000      188.0
# 50%    8.693000e+03  1960.000000      434.000000     301.000000      188.0
# 75%    1.201300e+04  1965.000000      562.000000     388.000000      188.0
# max    3.136756e+08  2018.000000      721.000000  166667.000000      188.0
#
#          LATITUDE   LONGITUDE
# count  273.000000  273.000000
# mean    33.884127 -118.333385
# std      0.075679    0.041168
# min     33.712579 -118.442873
# 25%     33.823017 -118.361604
# 50%     33.889938 -118.339825
# 75%     33.953739 -118.299207
# max     33.989008 -118.242705

# %%
# inspect 'Vacant Land' Property Type
south_bay[south_bay['PROPERTY TYPE'] == 'Vacant Land'].describe()
# Out:
#        ZIP OR POSTAL CODE         PRICE  BEDS  BATHS  SQUARE FEET  \
# count           46.000000  5.600000e+01   3.0    0.0          0.0
# mean         90459.108696  8.023998e+05   0.0    NaN          NaN
# std            226.549796  7.236594e+05   0.0    NaN          NaN
# min          90247.000000  1.340000e+05   0.0    NaN          NaN
# 25%          90275.000000  3.800000e+05   0.0    NaN          NaN
# 50%          90297.000000  5.250000e+05   0.0    NaN          NaN
# 75%          90731.000000  9.662500e+05   0.0    NaN          NaN
# max          90745.000000  3.125000e+06   0.0    NaN          NaN
#
#             LOT SIZE  YEAR BUILT  DAYS ON MARKET  $/SQUARE FEET  HOA/MONTH  \
# count      56.000000         0.0       56.000000            0.0        0.0
# mean    16307.410714         NaN      395.803571            NaN        NaN
# std     31739.495162         NaN      205.788454            NaN        NaN
# min      2120.000000         NaN      100.000000            NaN        NaN
# 25%      5552.500000         NaN      198.000000            NaN        NaN
# 50%      9539.500000         NaN      382.000000            NaN        NaN
# 75%     17197.750000         NaN      598.250000            NaN        NaN
# max    240608.000000         NaN      714.000000            NaN        NaN
#
#         LATITUDE   LONGITUDE
# count  56.000000   56.000000
# mean   33.813729 -118.331107
# std     0.082748    0.044567
# min    33.709628 -118.447281
# 25%    33.740054 -118.358161
# 50%    33.803782 -118.326383
# 75%    33.880477 -118.293530
# max    33.975688 -118.278700

# %%
# keep Property Type with values: Single Family Residential, Townhouse, Condo/Co-op, Mobile/Manufactured Home.
prop_types = ['Single Family Residential', 'Townhouse', 'Condo/Co-op', 'Mobile/Manufactured Home']

south_bay = south_bay[south_bay['PROPERTY TYPE'].isin(prop_types)]

# %%
# verify result
south_bay.groupby(['PROPERTY TYPE'])['SOLD DATE'].count()
# Out:
# PROPERTY TYPE
# Condo/Co-op                  2610
# Mobile/Manufactured Home      351
# Single Family Residential    9950
# Townhouse                    2606
# Name: SOLD DATE, dtype: int64

# %% [markdown]
# ADDRESS:

# %%
# view records with empty Address
south_bay[south_bay['ADDRESS'].isnull()]
# Out:
#        SOLD DATE              PROPERTY TYPE ADDRESS             CITY  \
# 1068  2018-12-21  Single Family Residential     NaN  Manhattan Beach
# 3555  2019-09-04                  Townhouse     NaN           Carson
# 3926  2019-02-25  Single Family Residential     NaN          Gardena
# 5677  2019-02-25  Single Family Residential     NaN          Gardena
# 10626 2018-06-22                Condo/Co-op     NaN         Torrance
# 16655 2018-06-22                Condo/Co-op     NaN         Torrance
# 16680 2018-04-13                Condo/Co-op     NaN         Torrance
#
#       STATE OR PROVINCE  ZIP OR POSTAL CODE    PRICE  BEDS  BATHS  \
# 1068                 CA             90266.0  3300000   4.0    3.5
# 3555                 CA             90745.0   465000   3.0    2.5
# 3926                 CA             90247.0   593750   3.0    2.0
# 5677                 CA             90247.0   593750   3.0    2.0
# 10626                CA             90502.0   450000   3.0    1.5
# 16655                CA             90502.0   450000   3.0    1.5
# 16680                CA             90505.0   458500   3.0    2.0
#
#                        LOCATION  ...  LOT SIZE  YEAR BUILT  DAYS ON MARKET  \
# 1068   143 - Manhattan Bch Tree  ...    5060.0      1990.0           400.0
# 3555         139 - South Carson  ...       NaN      1980.0           143.0
# 3926                        NaN  ...    5452.0      1961.0           331.0
# 5677                        NaN  ...    5452.0      1961.0           334.0
# 10626        123 - County Strip  ...  132433.0      1979.0           582.0
# 16655        123 - County Strip  ...  132433.0      1979.0           594.0
# 16680                       NaN  ...  984919.0      1963.0           664.0
#
#        $/SQUARE FEET  HOA/MONTH        MLS#   LATITUDE   LONGITUDE  \
# 1068           799.0        NaN  SB18269897  33.891926 -118.401617
# 3555           329.0      285.0  SB19140889  33.827920 -118.282972
# 3926           433.0        NaN    19423232  33.874884 -118.288451
# 5677           433.0        NaN    19423232  33.874884 -118.288451
# 10626          350.0        NaN  SB18111298  33.823876 -118.289422
# 16655          350.0        NaN  SB18111298  33.823876 -118.289422
# 16680          410.0      352.0    18309548  33.820458 -118.341884
#
#                                     FILENAME COLLECTION
# 1068           manhattan-beach_2.5M_plus.csv          1
# 3555                carson_nosfh_nocondo.csv          1
# 3926                harbor-gateway-north.csv          1
# 5677   gardena_sfh_south_of_red_bch_blvd.csv          1
# 10626                      carson_condos.csv          1
# 16655          torrance_condos-0_to_500K.csv          2
# 16680          torrance_condos-0_to_500K.csv          2
#
# [7 rows x 21 columns]

# %%
# drop rows with no address data
south_bay.dropna(subset=['ADDRESS'], axis=0, inplace=True)

# %%
# update addresses to mixed case 
south_bay['ADDRESS'] = south_bay['ADDRESS'].apply(lambda x: x.title())

# %% [markdown]
# CITY:

# %%
# change cities to mixed case
south_bay['CITY'] = south_bay['CITY'].astype(str).apply(lambda x: x.title())

# %%
# view rows with no CITY data
south_bay[south_bay['CITY'].isnull()]
# Out:
# Empty DataFrame
# Columns: [SOLD DATE, PROPERTY TYPE, ADDRESS, CITY, STATE OR PROVINCE, ZIP OR POSTAL CODE, PRICE, BEDS, BATHS, LOCATION, SQUARE FEET, LOT SIZE, YEAR BUILT, DAYS ON MARKET, $/SQUARE FEET, HOA/MONTH, MLS#, LATITUDE, LONGITUDE, FILENAME, COLLECTION]
# Index: []
#
# [0 rows x 21 columns]

# %%
# update missing City data
south_bay.at[3695, 'CITY'] = 'Harbor City'
south_bay.at[8764,'CITY'] = 'Palos Verdes Estates'

# %%
# group by City
south_bay.groupby(['CITY'])['SOLD DATE'].count()
# Out:
# CITY
# Carson                     998
# Compton                      3
# County - Los Angeles         4
# El Segundo                 250
# Gardena                    833
# Harbor                       1
# Harbor City                448
# Hawthorne                  840
# Hermosa Beach              429
# Inglewood                  667
# Ladera Heights               2
# Lawndale                   312
# Lennox                      19
# Lomita                     430
# Long Beach                   2
# Los Angeles               1155
# Los Feliz                    1
# Manhattan Beach            770
# Nan                          2
# Palos Verdes Estates       375
# Palos Verdes Peninsula      13
# Park Hills Heights           2
# Playa Del Rey              347
# Rancho Palos Verdes       1032
# Redondo Beach             1820
# Rolling Hills               39
# Rolling Hills Estates      270
# San Bernardino               1
# San Pedro                 1104
# Torrance                  3006
# Venice                       1
# View Park                    1
# Westchester                 99
# Wilmington                 234
# Name: SOLD DATE, dtype: int64

# %%
# check cities with under 5 or fewer sales 
small_city_count = ['Compton','County - Los Angeles', 'Harbor', 'Ladera Heights', 'Long Beach', 'Los Feliz',\
                'Park Hills Heights', 'San Bernardino', 'Venice', 'View Park']

city_check = south_bay[south_bay['CITY'].isin(small_city_count)]
city_check.to_csv('../data/interim/city_check.csv')

# %%
# create mapping for city names to update

small_city_map = {'County - Los Angeles': 'Los Angeles', 
                  'Los Feliz': 'Los Angeles', 'Harbor': 'Harbor City', 
                  'Ladera Heights': 'Los Angeles', 
                  'Park Hills Heights': 'Los Angeles', 
                  'View Park': 'Los Angeles', 'Venice': 'Playa Del Rey'}

# %%
# replace city names with mapping above 
south_bay.replace({'CITY' : small_city_map}, inplace=True)

# %%
# drop row with san bernardino city  
south_bay.drop(south_bay[south_bay['CITY'] == 'San Bernardino'].index, inplace=True)

# %%
# verify results
south_bay.groupby(['CITY'])['SOLD DATE'].count()
# Out:
# CITY
# Carson                     998
# Compton                      3
# El Segundo                 250
# Gardena                    833
# Harbor City                449
# Hawthorne                  840
# Hermosa Beach              429
# Inglewood                  667
# Lawndale                   312
# Lennox                      19
# Lomita                     430
# Long Beach                   2
# Los Angeles               1165
# Manhattan Beach            770
# Nan                          2
# Palos Verdes Estates       375
# Palos Verdes Peninsula      13
# Playa Del Rey              348
# Rancho Palos Verdes       1032
# Redondo Beach             1820
# Rolling Hills               39
# Rolling Hills Estates      270
# San Pedro                 1104
# Torrance                  3006
# Westchester                 99
# Wilmington                 234
# Name: SOLD DATE, dtype: int64

# %% [markdown]
# ZIP/POSTAL CODES:

# %%
# view rows with no zip code data
south_bay[south_bay['ZIP OR POSTAL CODE'].isnull()]
# Out:
# Empty DataFrame
# Columns: [SOLD DATE, PROPERTY TYPE, ADDRESS, CITY, STATE OR PROVINCE, ZIP OR POSTAL CODE, PRICE, BEDS, BATHS, LOCATION, SQUARE FEET, LOT SIZE, YEAR BUILT, DAYS ON MARKET, $/SQUARE FEET, HOA/MONTH, MLS#, LATITUDE, LONGITUDE, FILENAME, COLLECTION]
# Index: []
#
# [0 rows x 21 columns]

# %%
# check for zip code errors
zip_check = (south_bay['ZIP OR POSTAL CODE'] < 90000) | (south_bay['ZIP OR POSTAL CODE'] >= 99999)
print(south_bay.loc[:,['ADDRESS', 'PROPERTY TYPE', 'CITY', 'ZIP OR POSTAL CODE']][zip_check])
# Out:
#                        ADDRESS PROPERTY TYPE    CITY  ZIP OR POSTAL CODE
# 3340  1984 #7 Rolling Vista Dr     Townhouse  Lomita             70717.0
# 4616  1984 #7 Rolling Vista Dr     Townhouse  Lomita             70717.0

# %%
# update zip codes to from 70717 to 90717
south_bay.at[7501, 'ZIP OR POSTAL CODE'] = 90717.0
south_bay.at[10126,'ZIP OR POSTAL CODE'] = 90717.0

# %% [markdown]
# PRICE:

# %%
# check for min and max prices
south_bay[(south_bay['PRICE'] == south_bay['PRICE'].min()) | (south_bay['PRICE'] == south_bay['PRICE'].max())]
# Out:
#        SOLD DATE              PROPERTY TYPE                ADDRESS  \
# 3302  2020-01-08   Mobile/Manufactured Home     24200 Walnut St #5
# 15817 2018-02-27  Single Family Residential  417 Paseo De La Playa
# 16867 2020-01-08   Mobile/Manufactured Home     24200 Walnut St #5
# 18031 2018-02-27  Single Family Residential  417 Paseo De La Playa
#
#                 CITY STATE OR PROVINCE  ZIP OR POSTAL CODE     PRICE  BEDS  \
# 3302        Torrance                CA             90501.0        25   2.0
# 15817  Redondo Beach                CA             90277.0  22650000   7.0
# 16867       Torrance                CA             90501.0        25   2.0
# 18031  Redondo Beach                CA             90277.0  22650000   7.0
#
#        BATHS                 LOCATION  ...  LOT SIZE  YEAR BUILT  \
# 3302    1.00     129 - South Torrance  ...       NaN      1963.0
# 15817   8.75  128 - Hollywood Riviera  ...   62800.0      2005.0
# 16867   1.00     129 - South Torrance  ...       NaN      1963.0
# 18031   8.75  128 - Hollywood Riviera  ...   62800.0      2005.0
#
#        DAYS ON MARKET  $/SQUARE FEET  HOA/MONTH        MLS#   LATITUDE  \
# 3302             17.0            0.0        NaN  CV19264617  33.806188
# 15817           709.0         2221.0        NaN  PV17206016  33.810415
# 16867            29.0            0.0        NaN  CV19264617  33.806188
# 18031           709.0         2221.0        NaN  PV17206016  33.810415
#
#         LONGITUDE                               FILENAME COLLECTION
# 3302  -118.310948                    lomita_01_nosfh.csv          1
# 15817 -118.391070            redondo_sfh-4_plus_beds.csv          2
# 16867 -118.310948  torrance_nosfh-notownhome-nocondo.csv          2
# 18031 -118.391070           torrance_sfh-5-plus-beds.csv          2
#
# [4 rows x 21 columns]

# %%
# view price info
south_bay['PRICE'].describe()
# Out:
# count    1.550900e+04
# mean     9.846371e+05
# std      9.211453e+05
# min      2.500000e+01
# 25%      5.350000e+05
# 50%      7.250000e+05
# 75%      1.165000e+06
# max      2.265000e+07
# Name: PRICE, dtype: float64

# %%
# view low prices
south_bay[south_bay['PRICE'] < 10000]
# Out:
#        SOLD DATE              PROPERTY TYPE               ADDRESS       CITY  \
# 886   2018-06-16  Single Family Residential        120 E Hardy St  Inglewood
# 993   2019-03-26  Single Family Residential  9910 S Village Dr #1  Inglewood
# 3302  2020-01-08   Mobile/Manufactured Home    24200 Walnut St #5   Torrance
# 16867 2020-01-08   Mobile/Manufactured Home    24200 Walnut St #5   Torrance
#
#       STATE OR PROVINCE  ZIP OR POSTAL CODE  PRICE  BEDS  BATHS  \
# 886                  CA             90301.0   2100   2.0    1.0
# 993                  CA             90305.0   1775   1.0    1.0
# 3302                 CA             90501.0     25   2.0    1.0
# 16867                CA             90501.0     25   2.0    1.0
#
#                     LOCATION  ...  LOT SIZE  YEAR BUILT  DAYS ON MARKET  \
# 886    102 - South Inglewood  ...    3574.0      1926.0           585.0
# 993          North Inglewood  ...   13667.0      1958.0           302.0
# 3302    129 - South Torrance  ...       NaN      1963.0            17.0
# 16867   129 - South Torrance  ...       NaN      1963.0            29.0
#
#        $/SQUARE FEET  HOA/MONTH        MLS#   LATITUDE   LONGITUDE  \
# 886              2.0        NaN  IN18136584  33.948858 -118.353954
# 993              0.0        NaN   19-446172  33.946075 -118.328860
# 3302             0.0        NaN  CV19264617  33.806188 -118.310948
# 16867            0.0        NaN  CV19264617  33.806188 -118.310948
#
#                                     FILENAME COLLECTION
# 886      inglewood_03_sfh_2_beds_or_less.csv          1
# 993      inglewood_03_sfh_2_beds_or_less.csv          1
# 3302                     lomita_01_nosfh.csv          1
# 16867  torrance_nosfh-notownhome-nocondo.csv          2
#
# [4 rows x 21 columns]

# %%
# drop records where price < 10000
south_bay.drop(south_bay[south_bay['PRICE'] < 10000].index,axis=0,inplace=True)

# %% [markdown]
# BEDS:

# %%
# view empty data for Beds column 
south_bay[south_bay['BEDS'].isnull()]
# Out:
#        SOLD DATE PROPERTY TYPE          ADDRESS           CITY  \
# 8361  2018-03-27     Townhouse  3557 W 132Nd St      Hawthorne
# 18378 2019-01-08     Townhouse   2518 Gates Ave  Redondo Beach
#
#       STATE OR PROVINCE  ZIP OR POSTAL CODE    PRICE  BEDS  BATHS  \
# 8361                 CA             90250.0   595000   NaN    NaN
# 18378                CA             90278.0  1550000   NaN    NaN
#
#                                LOCATION  ...  LOT SIZE  YEAR BUILT  \
# 8361               110 - East Hawthorne  ...    7260.0      1940.0
# 18378  151 - N Redondo Bch/Villas North  ...    7500.0      1951.0
#
#        DAYS ON MARKET  $/SQUARE FEET  HOA/MONTH        MLS#   LATITUDE  \
# 8361            669.0          426.0        NaN  RS17252089  33.912505
# 18378           394.0          572.0        NaN  SB18283550  33.878096
#
#        LONGITUDE                       FILENAME COLLECTION
# 8361  -118.33494    hawthorne_nosfh_nocondo.csv          1
# 18378 -118.36480  redondo_townhome-0-2-beds.csv          2
#
# [2 rows x 21 columns]

# %%
#drop all rows with missing beds data
south_bay.dropna(subset=['BEDS'], axis=0, inplace=True)

# %%
# view range for num of beds
south_bay['BEDS'].describe()
# Out:
# count    15503.000000
# mean         3.086499
# std          1.094285
# min          0.000000
# 25%          2.000000
# 50%          3.000000
# 75%          4.000000
# max         32.000000
# Name: BEDS, dtype: float64

# %%
# display beds that are 0
south_bay[(south_bay['BEDS'] == 0)]
# Out:
#        SOLD DATE              PROPERTY TYPE                        ADDRESS  \
# 1288  2018-11-06  Single Family Residential                  2613 Crest Dr
# 1308  2019-08-09  Single Family Residential                    461 26Th St
# 1684  2019-09-20  Single Family Residential            13905 Inglewood Ave
# 4134  2018-04-24  Single Family Residential              10605 Compton Ave
# 4192  2018-12-01  Single Family Residential            9702 Wilmington Ave
# 4450  2018-02-16                Condo/Co-op          3601 W Hidden Ln #114
# 4494  2018-08-14                Condo/Co-op  6526 Ocean Crest Dr Unit A206
# 4503  2018-11-09                Condo/Co-op         3602 W Estates Ln #114
# 4515  2018-12-11                Condo/Co-op          3605 W Hidden Ln #212
# 4521  2019-04-19                Condo/Co-op  6526 Ocean Crest Dr Unit A308
# 4532  2019-01-17                Condo/Co-op         3604 W Estates Ln #112
# 4551  2019-03-22                Condo/Co-op          3605 W Hidden Ln #214
# 4562  2020-01-21                Condo/Co-op          3603 W Hidden Ln #114
# 4566  2018-07-09                Condo/Co-op         3602 W Estates Ln #112
# 4606  2019-09-03                Condo/Co-op          3603 W Hidden Ln #314
# 4778  2018-02-06                Condo/Co-op           1300 The Strand #131
# 5185  2019-09-20  Single Family Residential            13905 Inglewood Ave
# 10350 2018-10-05                Condo/Co-op         13125 Central Ave #203
# 10458 2019-05-23                Condo/Co-op         23332 Sesame St Unit A
# 10507 2019-05-15                Condo/Co-op         23300 Sesame St Unit B
# 10615 2018-03-02                Condo/Co-op         23300 Sesame St Unit C
# 11158 2018-03-23  Single Family Residential              1122 E Anaheim St
# 11314 2018-09-07  Single Family Residential          820 N Wilmington Blvd
# 11315 2018-09-07  Single Family Residential          814 N Wilmington Blvd
# 12290 2020-01-16  Single Family Residential                  618 W 40Th St
# 14200 2019-08-23                Condo/Co-op         785 W 19Th St Unit 12B
# 16501 2019-02-13                Condo/Co-op        3550 Torrance Blvd #313
# 16625 2019-05-23                Condo/Co-op         23332 Sesame St Unit A
# 16733 2019-05-15                Condo/Co-op         23300 Sesame St Unit B
# 16751 2018-03-02                Condo/Co-op         23300 Sesame St Unit C
# 16776 2018-08-21                Condo/Co-op        3550 Torrance Blvd #211
# 17154 2018-09-28                Condo/Co-op               620 The Vlg #302
# 17158 2019-09-24                Condo/Co-op               610 The Vlg #302
# 17165 2018-02-21                Condo/Co-op               250 The Vlg #205
# 17169 2018-08-24                Condo/Co-op               250 The Vlg #105
# 17242 2018-06-28                Condo/Co-op               630 The Vlg #302
# 17349 2018-12-17                Condo/Co-op               610 The Vlg #202
# 18196 2018-08-14                Condo/Co-op  6526 Ocean Crest Dr Unit A206
# 18197 2019-04-19                Condo/Co-op  6526 Ocean Crest Dr Unit A308
#
#                         CITY STATE OR PROVINCE  ZIP OR POSTAL CODE    PRICE  \
# 1288         Manhattan Beach                CA             90266.0  4530040
# 1308         Manhattan Beach                CA             90266.0  2700000
# 1684               Hawthorne                CA             90250.0   470000
# 4134             Los Angeles                CA             90002.0   165000
# 4192             Los Angeles                CA             90002.0   193000
# 4450   Rolling Hills Estates                CA             90274.0   295000
# 4494     Rancho Palos Verdes                CA             90275.0   340000
# 4503   Rolling Hills Estates                CA             90274.0   295000
# 4515   Rolling Hills Estates                CA             90274.0   307000
# 4521     Rancho Palos Verdes                CA             90275.0   370000
# 4532   Rolling Hills Estates                CA             90274.0   284000
# 4551   Rolling Hills Estates                CA             90274.0   292000
# 4562   Rolling Hills Estates                CA             90274.0   290000
# 4566   Rolling Hills Estates                CA             90274.0   285000
# 4606   Rolling Hills Estates                CA             90274.0   285000
# 4778           Hermosa Beach                CA             90254.0   650000
# 5185               Hawthorne                CA             90250.0   470000
# 10350              Hawthorne                CA             90250.0   572000
# 10458               Torrance                CA             90502.0   225000
# 10507               Torrance                CA             90502.0   230000
# 10615               Torrance                CA             90502.0   222000
# 11158             Wilmington                CA             90744.0   297000
# 11314             Wilmington                CA             90744.0   360000
# 11315             Wilmington                CA             90744.0   360000
# 12290              San Pedro                CA             90731.0  1070000
# 14200              San Pedro                CA             90731.0   237900
# 16501               Torrance                CA             90503.0   260000
# 16625               Torrance                CA             90502.0   225000
# 16733               Torrance                CA             90502.0   230000
# 16751               Torrance                CA             90502.0   222000
# 16776               Torrance                CA             90503.0   249000
# 17154          Redondo Beach                CA             90277.0   460000
# 17158          Redondo Beach                CA             90277.0   480000
# 17165          Redondo Beach                CA             90277.0   580000
# 17169          Redondo Beach                CA             90277.0   585000
# 17242          Redondo Beach                CA             90277.0   470000
# 17349          Redondo Beach                CA             90277.0   460000
# 18196    Rancho Palos Verdes                CA             90275.0   340000
# 18197    Rancho Palos Verdes                CA             90275.0   370000
#
#        BEDS  BATHS                      LOCATION  ...  LOT SIZE  YEAR BUILT  \
# 1288    0.0    NaN      142 - Manhattan Bch Sand  ...    3512.0      1935.0
# 1308    0.0    NaN      142 - Manhattan Bch Sand  ...    2698.0      1953.0
# 1684    0.0   2.00          110 - East Hawthorne  ...    3763.0      1954.0
# 4134    0.0    NaN             699 - Not Defined  ...    3600.0      1913.0
# 4192    0.0   1.50      C37 - Metropolitan South  ...    4493.0      1958.0
# 4450    0.0   1.00             165 - PV Dr North  ...  433780.0      1973.0
# 4494    0.0   1.00            171 - Country Club  ...  167165.0      1973.0
# 4503    0.0   1.00             165 - PV Dr North  ...  433780.0      1973.0
# 4515    0.0   1.00             165 - PV Dr North  ...  433780.0      1973.0
# 4521    0.0   1.00            171 - Country Club  ...  167165.0      1973.0
# 4532    0.0   1.00             165 - PV Dr North  ...  433780.0      1973.0
# 4551    0.0   1.00             165 - PV Dr North  ...  433780.0      1973.0
# 4562    0.0   1.00             165 - PV Dr North  ...  433780.0      1973.0
# 4566    0.0   1.00             165 - PV Dr North  ...  433780.0      1973.0
# 4606    0.0   1.00             165 - PV Dr North  ...  433780.0      1973.0
# 4778    0.0   1.00        148 - Hermosa Bch Sand  ...   14384.0      2001.0
# 5185    0.0   2.00          110 - East Hawthorne  ...    3763.0      1954.0
# 10350   0.0   1.00           Holly Glen/Del Aire  ...    7920.0      2013.0
# 10458   0.0   1.00            123 - County Strip  ...  296172.0      1973.0
# 10507   0.0   1.00            123 - County Strip  ...  313239.0      1973.0
# 10615   0.0   1.00                  County Strip  ...  313202.0      1973.0
# 11158   0.0    NaN               East Wilmington  ...    4800.0      1922.0
# 11314   0.0    NaN               West Wilmington  ...    7584.0      1950.0
# 11315   0.0    NaN               West Wilmington  ...    7584.0      1950.0
# 12290   0.0   0.75            181 - Point Fermin  ...    1000.0      1921.0
# 14200   0.0   1.00           183 - Vista Del Oro  ...    8891.0      1978.0
# 16501   0.0   1.00        126 - Central Torrance  ...   41131.0      2006.0
# 16625   0.0   1.00            123 - County Strip  ...  296172.0      1973.0
# 16733   0.0   1.00            123 - County Strip  ...  313239.0      1973.0
# 16751   0.0   1.00                  County Strip  ...  313202.0      1973.0
# 16776   0.0   1.00           131 - West Torrance  ...   41131.0      2006.0
# 17154   0.0   1.00  157 - S Redondo Bch W of PCH  ...  272965.0      1974.0
# 17158   0.0   1.00  157 - S Redondo Bch W of PCH  ...  272965.0      1974.0
# 17165   0.0   1.00  157 - S Redondo Bch W of PCH  ...  146594.0      1978.0
# 17169   0.0   1.00  157 - S Redondo Bch W of PCH  ...  146594.0      1978.0
# 17242   0.0   1.00  157 - S Redondo Bch W of PCH  ...  272965.0      1974.0
# 17349   0.0   1.00  157 - S Redondo Bch W of PCH  ...  272965.0      1974.0
# 18196   0.0   1.00            171 - Country Club  ...  167165.0      1973.0
# 18197   0.0   1.00            171 - Country Club  ...  167165.0      1973.0
#
#        DAYS ON MARKET  $/SQUARE FEET  HOA/MONTH        MLS#   LATITUDE  \
# 1288            445.0        45300.0        NaN  SB18024122  33.894668
# 1308            169.0        27000.0        NaN  SB19039219  33.895254
# 1684            124.0          285.0        NaN  DW19224759  33.905094
# 4134            641.0          125.0        NaN  DW17279455  33.939427
# 4192            420.0          268.0        NaN  DW18253758  33.948125
# 4450            708.0          670.0      325.0  PV18009090  33.785169
# 4494            529.0          789.0      282.0  PV18148707  33.763503
# 4503            442.0          670.0      338.0  SB18222834  33.785169
# 4515            410.0          698.0      338.0  SB18233933  33.785169
# 4521            281.0          858.0      291.0  CV19049069  33.763503
# 4532            373.0          645.0      338.0  SB18265934  33.785169
# 4551            309.0          664.0      338.0  SB18278806  33.785169
# 4562              4.0          659.0      338.0  PV19219659  33.785169
# 4566            565.0          648.0      325.0  SB18125748  33.785169
# 4606            144.0          648.0      342.0  SB19163679  33.785169
# 4778            718.0         1477.0      845.0  SB18001845  33.863304
# 5185            127.0          285.0        NaN  DW19224759  33.905094
# 10350           477.0          643.0      480.0   18-379800  33.914066
# 10458           247.0          542.0      245.0  SB19004056  33.812395
# 10507           255.0          554.0      245.0  PW18274857  33.814806
# 10615           694.0          535.0      246.0   18-301630  33.814806
# 11158           673.0          197.0        NaN   17-248776  33.780515
# 11314           505.0            NaN        NaN   18-311382  33.779996
# 11315           505.0          250.0        NaN   18-311388  33.779934
# 12290            22.0         2140.0        NaN  SB19274676  33.708065
# 14200           168.0          599.0      200.0  PV19144068  33.726675
# 16501           358.0          531.0      319.0  SB19009646  33.837220
# 16625           259.0          542.0      245.0  SB19004056  33.812395
# 16733           267.0          554.0      245.0  PW18274857  33.814806
# 16751           706.0          535.0      246.0   18-301630  33.814806
# 16776           534.0          519.0      266.0  IG18138040  33.837220
# 17154           496.0         1122.0      265.0  PV18194506  33.839671
# 17158           135.0         1171.0      268.0  SB19119455  33.839671
# 17165           715.0         1005.0      387.0  SB18013059  33.842833
# 17169           531.0         1014.0      387.0  SB18192453  33.842833
# 17242           588.0         1146.0      268.0  SB18057884  33.839671
# 17349           416.0         1122.0      265.0  SB18261977  33.839671
# 18196           542.0          789.0      282.0  PV18148707  33.763503
# 18197           294.0          858.0      291.0  CV19049069  33.763503
#
#         LONGITUDE                          FILENAME COLLECTION
# 1288  -118.414787     manhattan-beach_2.5M_plus.csv          1
# 1308  -118.412626     manhattan-beach_2.5M_plus.csv          1
# 1684  -118.361558                      del-aire.csv          1
# 4134  -118.246381             watts_0_to_3_beds.csv          1
# 4192  -118.239008             watts_0_to_3_beds.csv          1
# 4450  -118.341640  rolling-hills-estates_no_sfh.csv          1
# 4494  -118.393794  rolling-hills-estates_no_sfh.csv          1
# 4503  -118.341640  rolling-hills-estates_no_sfh.csv          1
# 4515  -118.341640  rolling-hills-estates_no_sfh.csv          1
# 4521  -118.393794  rolling-hills-estates_no_sfh.csv          1
# 4532  -118.341640  rolling-hills-estates_no_sfh.csv          1
# 4551  -118.341640  rolling-hills-estates_no_sfh.csv          1
# 4562  -118.341640  rolling-hills-estates_no_sfh.csv          1
# 4566  -118.341640  rolling-hills-estates_no_sfh.csv          1
# 4606  -118.341640  rolling-hills-estates_no_sfh.csv          1
# 4778  -118.401526          hermosa-beach_no_sfh.csv          1
# 5185  -118.361558    hawthorne_sfh_2bed_or_less.csv          1
# 10350 -118.376638              hawthorne_condos.csv          1
# 10458 -118.288634                 carson_condos.csv          1
# 10507 -118.288335                 carson_condos.csv          1
# 10615 -118.288335                 carson_condos.csv          1
# 11158 -118.248528        wilmington_0_to_3_beds.csv          1
# 11314 -118.274241        wilmington_0_to_3_beds.csv          1
# 11315 -118.273972        wilmington_0_to_3_beds.csv          1
# 12290 -118.290324       san-pedro_sfh-800K-plus.csv          2
# 14200 -118.294365              san-pedro_condos.csv          2
# 16501 -118.348118     torrance_condos-0_to_500K.csv          2
# 16625 -118.288634     torrance_condos-0_to_500K.csv          2
# 16733 -118.288335     torrance_condos-0_to_500K.csv          2
# 16751 -118.288335     torrance_condos-0_to_500K.csv          2
# 16776 -118.348118     torrance_condos-0_to_500K.csv          2
# 17154 -118.389202                redondo_condos.csv          2
# 17158 -118.389202                redondo_condos.csv          2
# 17165 -118.390103                redondo_condos.csv          2
# 17169 -118.390103                redondo_condos.csv          2
# 17242 -118.389202                redondo_condos.csv          2
# 17349 -118.389202                redondo_condos.csv          2
# 18196 -118.393794     rancho-palos-verdes_nosfh.csv          2
# 18197 -118.393794     rancho-palos-verdes_nosfh.csv          2
#
# [39 rows x 21 columns]

# %% [markdown]
# BATHS:

# %%
# view empty data for Baths column 
south_bay[south_bay['BATHS'].isnull()]
# Out:
#        SOLD DATE              PROPERTY TYPE                ADDRESS  \
# 1288  2018-11-06  Single Family Residential          2613 Crest Dr
# 1308  2019-08-09  Single Family Residential            461 26Th St
# 4134  2018-04-24  Single Family Residential      10605 Compton Ave
# 7369  2018-10-25  Single Family Residential          3529 Pine Ave
# 8806  2019-12-20                  Townhouse         546 W Kelso St
# 10189 2018-04-02  Single Family Residential        22003 Meyler St
# 11158 2018-03-23  Single Family Residential      1122 E Anaheim St
# 11314 2018-09-07  Single Family Residential  820 N Wilmington Blvd
# 11315 2018-09-07  Single Family Residential  814 N Wilmington Blvd
# 14818 2018-04-02  Single Family Residential        22003 Meyler St
#
#                   CITY STATE OR PROVINCE  ZIP OR POSTAL CODE    PRICE  BEDS  \
# 1288   Manhattan Beach                CA             90266.0  4530040   0.0
# 1308   Manhattan Beach                CA             90266.0  2700000   0.0
# 4134       Los Angeles                CA             90002.0   165000   0.0
# 7369   Manhattan Beach                CA             90266.0  2149000   4.0
# 8806         Inglewood                CA             90301.0  1208888  10.0
# 10189         Torrance                CA             90502.0   742000   3.0
# 11158       Wilmington                CA             90744.0   297000   0.0
# 11314       Wilmington                CA             90744.0   360000   0.0
# 11315       Wilmington                CA             90744.0   360000   0.0
# 14818         Torrance                CA             90502.0   742000   3.0
#
#        BATHS                  LOCATION  ...  LOT SIZE  YEAR BUILT  \
# 1288     NaN  142 - Manhattan Bch Sand  ...    3512.0      1935.0
# 1308     NaN  142 - Manhattan Bch Sand  ...    2698.0      1953.0
# 4134     NaN         699 - Not Defined  ...    3600.0      1913.0
# 7369     NaN  143 - Manhattan Bch Tree  ...    4640.0      1972.0
# 8806     NaN     101 - North Inglewood  ...    6000.0      2019.0
# 10189    NaN        123 - County Strip  ...    4970.0      2018.0
# 11158    NaN           East Wilmington  ...    4800.0      1922.0
# 11314    NaN           West Wilmington  ...    7584.0      1950.0
# 11315    NaN           West Wilmington  ...    7584.0      1950.0
# 14818    NaN        123 - County Strip  ...    4970.0      2018.0
#
#        DAYS ON MARKET  $/SQUARE FEET  HOA/MONTH        MLS#   LATITUDE  \
# 1288            445.0        45300.0        NaN  SB18024122  33.894668
# 1308            169.0        27000.0        NaN  SB19039219  33.895254
# 4134            641.0          125.0        NaN  DW17279455  33.939427
# 7369            457.0          711.0        NaN  SB18230875  33.900901
# 8806             33.0          336.0        NaN  SB19239438  33.958540
# 10189           663.0          328.0        NaN  SB18010337  33.827959
# 11158           673.0          197.0        NaN   17-248776  33.780515
# 11314           505.0            NaN        NaN   18-311382  33.779996
# 11315           505.0          250.0        NaN   18-311388  33.779934
# 14818           675.0          328.0        NaN  SB18010337  33.827959
#
#         LONGITUDE                        FILENAME COLLECTION
# 1288  -118.414787   manhattan-beach_2.5M_plus.csv          1
# 1308  -118.412626   manhattan-beach_2.5M_plus.csv          1
# 4134  -118.246381           watts_0_to_3_beds.csv          1
# 7369  -118.399192    manhattan-beach_2.5M_max.csv          1
# 8806  -118.365872  inglewood_01_noSFH_nocondo.csv          1
# 10189 -118.294971        carson_sfh_600K_plus.csv          1
# 11158 -118.248528      wilmington_0_to_3_beds.csv          1
# 11314 -118.274241      wilmington_0_to_3_beds.csv          1
# 11315 -118.273972      wilmington_0_to_3_beds.csv          1
# 14818 -118.294971       torrance_sfh-700-800k.csv          2
#
# [10 rows x 21 columns]

# %%
#drop all rows with missing baths data
south_bay.dropna(subset=['BATHS'], axis=0, inplace=True)

# %%
# view range for num of baths
south_bay['BATHS'].describe()
# Out:
# count    15493.000000
# mean         2.274963
# std          0.990112
# min          0.500000
# 25%          1.750000
# 50%          2.000000
# 75%          2.750000
# max         25.000000
# Name: BATHS, dtype: float64

# %% [markdown]
# BED/BATHS:

# %%
# view records with large amount of bedrooms or bathrooms
south_bay[(south_bay['BEDS'] > 10) | (south_bay['BATHS'] > 10)]
# Out:
#        SOLD DATE              PROPERTY TYPE                 ADDRESS  \
# 3882  2018-05-16                  Townhouse          530 W 168Th St
# 6417  2018-05-16                  Townhouse          530 W 168Th St
# 8890  2018-10-22                  Townhouse         3533 W 108Th St
# 8989  2018-06-22                  Townhouse      9725 Crenshaw Blvd
# 9498  2018-10-30  Single Family Residential         1 Buggy Whip Dr
# 9801  2018-04-16                  Townhouse           232 E 79Th St
# 10003 2018-02-27                  Townhouse           637 E 83Rd St
# 12702 2018-07-06                  Townhouse  2413 W Vanderbilt Ln W
# 15575 2018-04-11                  Townhouse              740 5Th St
# 18040 2018-10-22  Single Family Residential          3642 Garnet St
#
#                 CITY STATE OR PROVINCE  ZIP OR POSTAL CODE     PRICE  BEDS  \
# 3882         Gardena                CA             90248.0    995000  12.0
# 6417         Gardena                CA             90248.0    995000  12.0
# 8890       Inglewood                CA             90303.0   1000000  22.0
# 8989       Inglewood                CA             90305.0   1299999  32.0
# 9498   Rolling Hills                CA             90274.0  22400000   9.0
# 9801     Los Angeles                CA             90003.0    600000  21.0
# 10003    Los Angeles                CA             90001.0    750000  20.0
# 12702  Redondo Beach                CA             90278.0   1425000  20.0
# 15575      San Pedro                CA             90731.0    675000  18.0
# 18040       Torrance                CA             90503.0    800000  11.0
#
#        BATHS                          LOCATION  ...  LOT SIZE  YEAR BUILT  \
# 3882     6.0               116 - North Gateway  ...   11648.0      1915.0
# 6417     6.0               116 - North Gateway  ...   11648.0      1915.0
# 8890    11.0             102 - South Inglewood  ...    9067.0      1927.0
# 8989    16.0                 699 - Not Defined  ...    7192.0      1955.0
# 9498    25.0                     Rolling Hills  ...  322344.0      2001.0
# 9801     9.0          C37 - Metropolitan South  ...    5555.0      1959.0
# 10003   12.0          C37 - Metropolitan South  ...    5104.0      2015.0
# 12702   16.0  151 - N Redondo Bch/Villas North  ...    7491.0      1946.0
# 15575    9.0               183 - Vista Del Oro  ...    5002.0      1902.0
# 18040    7.0               131 - West Torrance  ...    9682.0      1973.0
#
#        DAYS ON MARKET  $/SQUARE FEET  HOA/MONTH        MLS#   LATITUDE  \
# 3882            616.0          291.0        NaN  SB18077856  33.879114
# 6417            619.0          291.0        NaN  SB18077856  33.879114
# 8890            457.0          283.0        NaN  SB18046396  33.938010
# 8989            579.0            NaN        NaN  RS18001633  33.947687
# 9498            449.0          439.0     6500.0   18-311552  33.760302
# 9801            649.0          251.0        NaN  DW17199679  33.967653
# 10003           697.0          208.0        NaN  CV17175097  33.963935
# 12702           580.0          651.0        NaN  SB18135934  33.872030
# 15575           667.0          289.0        NaN  PV17270018  33.739883
# 18040           472.0          148.0        NaN  PW18198352  33.842953
#
#         LONGITUDE                         FILENAME COLLECTION
# 3882  -118.283701         harbor-gateway-north.csv          1
# 6417  -118.283701     gardena_01_nosfh_nocondo.csv          1
# 8890  -118.333944   inglewood_01_noSFH_nocondo.csv          1
# 8989  -118.327046   inglewood_01_noSFH_nocondo.csv          1
# 9498  -118.356741                rolling-hills.csv          1
# 9801  -118.270592         florence_4_plus_beds.csv          1
# 10003 -118.263649         florence_4_plus_beds.csv          1
# 12702 -118.367361  redondo_townhome-4plus_beds.csv          2
# 15575 -118.293155          san-pedro_townhomes.csv          2
# 18040 -118.350244     torrance_sfh-5-plus-beds.csv          2
#
# [10 rows x 21 columns]

# %%
# drop SFR on 1 Buggy Whip Dr and at 3642 Garnet St - indexes 10157, 18145
south_bay.drop(south_bay[(south_bay['ADDRESS'] == '1 Buggy Whip Dr')|\
                         (south_bay['ADDRESS'] == '3642 Garnet St')].index,axis=0,inplace=True)

# %% [markdown]
# LOCATION/NEIGHBORHOOD:

# %%
# view location data
south_bay.groupby(['LOCATION'])['SOLD DATE'].count()
# Out:
# LOCATION
# 101 - North Inglewood        193
# 102 - South Inglewood        130
# 103 - Ladera Heights           2
# 105 - Lennox                  46
# 107 - Holly Glen/Del Aire    373
#                             ...
# West Torrance                 12
# West Wilmington                6
# Westchester                  515
# Westside                       1
# Wilmington                     1
# Name: SOLD DATE, Length: 207, dtype: int64

# %%
# create new "neighborhood" column based on filename
# change string from filename like 'alondra-park_condo.csv' to 'Alondra Park'
south_bay['NEIGHBORHOOD'] = south_bay['FILENAME'].apply(lambda x: x.split("_")[0]\
                                                        .split(".")[0].title().replace('-',' '))

# %%
# verify new column information
south_bay.groupby(['NEIGHBORHOOD'])['SOLD DATE'].count()
# Out:
# NEIGHBORHOOD
# Alondra Park               71
# Carson                   1463
# Del Aire                  145
# El Segundo                252
# Florence                  158
# Gardena                   642
# Harbor City               348
# Harbor Gateway North      117
# Harbor Gateway South      117
# Hawthorne                 756
# Hermosa Beach             382
# Inglewood                 792
# Lawndale                  230
# Lennox                     40
# Lomita                    353
# Manhattan                 166
# Manhattan Beach           572
# Palos Verdes Estates      346
# Playa Del Rey             411
# Rancho Palos Verdes       893
# Redondo                  1725
# Rolling Hills              37
# Rolling Hills Estates     486
# San Pedro                1118
# Torrance                 2751
# Watts                     297
# Westchester               585
# Wilmington                238
# Name: SOLD DATE, dtype: int64

# %%
# update Redondo to Redondo Beach and Manhattan to Manhattan Beach
south_bay.replace({'NEIGHBORHOOD' : {'Redondo': 'Redondo Beach', 'Manhattan': 'Manhattan Beach'}}, inplace=True)

# %%
# drop original location column
south_bay.drop('LOCATION', axis=1, inplace=True)

# %%
south_bay.columns
# Out:
# Index(['SOLD DATE', 'PROPERTY TYPE', 'ADDRESS', 'CITY', 'STATE OR PROVINCE',
#        'ZIP OR POSTAL CODE', 'PRICE', 'BEDS', 'BATHS', 'SQUARE FEET',
#        'LOT SIZE', 'YEAR BUILT', 'DAYS ON MARKET', '$/SQUARE FEET',
#        'HOA/MONTH', 'MLS#', 'LATITUDE', 'LONGITUDE', 'FILENAME', 'COLLECTION',
#        'NEIGHBORHOOD'],
#       dtype='object')

# %% [markdown]
# SQUARE FEET:

# %%
# view empty data for Square Feet column 
south_bay[south_bay['SQUARE FEET'].isnull()]
# Out:
#        SOLD DATE              PROPERTY TYPE                     ADDRESS  \
# 2342  2018-06-15  Single Family Residential            1132 Levinson St
# 3398  2018-10-01   Mobile/Manufactured Home              2350 250Th #58
# 3459  2019-03-26   Mobile/Manufactured Home       17701 Avalon Blvd #68
# 3480  2019-07-31   Mobile/Manufactured Home      17700 Avalon Blvd #383
# 3481  2019-09-24   Mobile/Manufactured Home       17700 Avalon Blvd #36
# 3489  2018-03-05   Mobile/Manufactured Home    1502 E Carson St St #103
# 3548  2018-04-17   Mobile/Manufactured Home                 1065 Lomita
# 3699  2019-08-29   Mobile/Manufactured Home              437 Carson #57
# 3700  2019-09-02   Mobile/Manufactured Home       21207 Avalon Blvd #83
# 3707  2019-11-18   Mobile/Manufactured Home          715 W 220Th St #39
# 3726  2018-10-31   Mobile/Manufactured Home       21111 Dolores St #130
# 3728  2018-09-24   Mobile/Manufactured Home    22516 Normandie Unit B43
# 3731  2018-11-02   Mobile/Manufactured Home       1065 Lomita Blvd #162
# 3745  2019-08-16   Mobile/Manufactured Home       1065 Lomita Blvd #191
# 5709  2019-11-04  Single Family Residential         16908 Normandie Ave
# 5859  2019-09-13  Single Family Residential              312 W Olive St
# 6579  2019-08-28   Mobile/Manufactured Home     16949 S Western Ave #28
# 8989  2018-06-22                  Townhouse          9725 Crenshaw Blvd
# 11134 2018-12-31   Mobile/Manufactured Home        1000 Figueroa St #52
# 11258 2018-08-17   Mobile/Manufactured Home        1000 Figueroa St #31
# 11381 2019-09-09  Single Family Residential              6015 W 83Rd Pl
# 14492 2019-02-13   Mobile/Manufactured Home         2275 W 25Th St #228
# 14530 2018-12-14   Mobile/Manufactured Home              2275 W 25Th #5
# 16056 2020-01-08   Mobile/Manufactured Home    18801 Hawthorne Blvd #97
# 16117 2018-04-18   Mobile/Manufactured Home         18801 Hawthorne #18
# 16124 2018-07-06   Mobile/Manufactured Home              2345 190Th #74
# 16126 2018-05-01   Mobile/Manufactured Home            2345 190Th St #1
# 16127 2019-05-08   Mobile/Manufactured Home              2345 190Th #60
# 16807 2018-10-03   Mobile/Manufactured Home       23701 Western Ave #70
# 16813 2018-04-18   Mobile/Manufactured Home         18801 Hawthorne #18
# 16817 2018-07-06   Mobile/Manufactured Home              2345 190Th #74
# 16819 2018-05-01   Mobile/Manufactured Home            2345 190Th St #1
# 16820 2019-05-08   Mobile/Manufactured Home              2345 190Th #60
# 16830 2019-11-18   Mobile/Manufactured Home          715 W 220Th St #39
# 16864 2020-01-14   Mobile/Manufactured Home           20550 Earl St #25
# 16883 2018-09-24   Mobile/Manufactured Home    22516 Normandie Unit B43
# 16930 2019-11-15   Mobile/Manufactured Home  2550 Pacific Coast Hwy #83
# 16963 2018-11-08   Mobile/Manufactured Home    23701 S Western Ave #232
# 16964 2018-10-19   Mobile/Manufactured Home    23701 S Western Ave #213
# 16974 2018-11-01   Mobile/Manufactured Home          20620 Palm Way #39
# 16975 2018-10-15   Mobile/Manufactured Home          20554 Palm Way #33
# 16977 2019-07-26   Mobile/Manufactured Home              20558 Palm Way
# 16978 2019-08-13   Mobile/Manufactured Home              20556 Vista Dr
# 16993 2018-06-05   Mobile/Manufactured Home           20550 Earl St #16
# 16994 2018-08-21   Mobile/Manufactured Home            20550 Earl St #1
# 16995 2018-09-28   Mobile/Manufactured Home           20550 Earl St #43
# 16997 2018-08-09   Mobile/Manufactured Home              20550 Earl #28
# 16999 2018-07-24   Mobile/Manufactured Home           20550 Earl St #15
# 17000 2018-02-20   Mobile/Manufactured Home           20550 Earl St #32
# 17001 2018-02-14   Mobile/Manufactured Home           20550 Earl St #24
# 17002 2018-03-30   Mobile/Manufactured Home           20550 Earl St #48
# 17003 2018-02-28   Mobile/Manufactured Home           20550 Earl St #30
# 17004 2018-07-27   Mobile/Manufactured Home           20550 Earl St #33
# 17005 2018-02-26   Mobile/Manufactured Home           20550 Earl St #38
# 17016 2020-01-08   Mobile/Manufactured Home    18801 Hawthorne Blvd #97
# 17042 2018-05-01   Mobile/Manufactured Home    23701 S Western Ave #178
# 17051 2018-08-01   Mobile/Manufactured Home    23701 S Western Ave #146
# 18050 2018-06-15  Single Family Residential            1132 Levinson St
#
#                 CITY STATE OR PROVINCE  ZIP OR POSTAL CODE    PRICE  BEDS  \
# 2342     Los Angeles                CA             90502.0   557000   5.0
# 3398          Lomita                CA             90717.0    45000   1.0
# 3459          Carson                CA             90746.0   180000   2.0
# 3480          Carson                CA             90746.0   245000   3.0
# 3481          Carson                CA             90746.0   150000   2.0
# 3489          Carson                CA             90745.0   175000   1.0
# 3548     Harbor City                CA             90710.0   160000   2.0
# 3699          Carson                CA             90745.0    47500   1.0
# 3700          Carson                CA             90746.0   200000   2.0
# 3707        Torrance                CA             90502.0    30000   1.0
# 3726          Carson                CA             90745.0   170000   3.0
# 3728        Torrance                CA             90502.0    22000   1.0
# 3731     Harbor City                CA             90710.0   155000   2.0
# 3745     Harbor City                CA             90710.0    82500   2.0
# 5709         Gardena                CA             90247.0   800000   5.0
# 5859     Los Angeles                CA             90301.0   610000   3.0
# 6579         Gardena                CA             90247.0    45000   1.0
# 8989       Inglewood                CA             90305.0  1299999  32.0
# 11134     Wilmington                CA             90744.0   100000   3.0
# 11258     Wilmington                CA             90744.0    60000   2.0
# 11381    Los Angeles                CA             90045.0  1038487   3.0
# 14492      San Pedro                CA             90732.0   180000   3.0
# 14530      San Pedro                CA             90732.0   150000   3.0
# 16056       Torrance                CA             90504.0    78500   2.0
# 16117       Torrance                CA             90504.0    70000   2.0
# 16124  Redondo Beach                CA             90278.0    62000   1.0
# 16126  Redondo Beach                CA             90278.0   133500   2.0
# 16127  Redondo Beach                CA             90278.0    65000   2.0
# 16807       Torrance                CA             90501.0    35000   2.0
# 16813       Torrance                CA             90504.0    70000   2.0
# 16817  Redondo Beach                CA             90278.0    62000   1.0
# 16819  Redondo Beach                CA             90278.0   133500   2.0
# 16820  Redondo Beach                CA             90278.0    65000   2.0
# 16830       Torrance                CA             90502.0    30000   1.0
# 16864       Torrance                CA             90503.0    80000   1.0
# 16883       Torrance                CA             90502.0    22000   1.0
# 16930       Torrance                CA             90505.0   185000   2.0
# 16963       Torrance                CA             90501.0    39000   3.0
# 16964       Torrance                CA             90501.0    85000   3.0
# 16974       Torrance                CA             90503.0   195000   2.0
# 16975       Torrance                CA             90503.0    84500   1.0
# 16977       Torrance                CA             90503.0    95000   3.0
# 16978       Torrance                CA             90503.0   172500   1.0
# 16993       Torrance                CA             90503.0    78000   2.0
# 16994       Torrance                CA             90503.0    93000   2.0
# 16995       Torrance                CA             90503.0    54900   1.0
# 16997       Torrance                CA             90503.0   116000   3.0
# 16999       Torrance                CA             90503.0    59000   1.0
# 17000       Torrance                CA             90503.0    63000   2.0
# 17001       Torrance                CA             90503.0    57500   2.0
# 17002       Torrance                CA             90503.0    50000   1.0
# 17003       Torrance                CA             90503.0   120000   3.0
# 17004       Torrance                CA             90503.0    56500   1.0
# 17005       Torrance                CA             90503.0   100000   2.0
# 17016       Torrance                CA             90504.0    78500   2.0
# 17042       Torrance                CA             90501.0    40500   2.0
# 17051       Torrance                CA             90501.0    62500   2.0
# 18050    Los Angeles                CA             90502.0   557000   5.0
#
#        BATHS  SQUARE FEET  ...  YEAR BUILT  DAYS ON MARKET  $/SQUARE FEET  \
# 2342    2.00          NaN  ...      1959.0           589.0            NaN
# 3398    1.00          NaN  ...      1980.0           481.0            NaN
# 3459    1.75          NaN  ...         NaN           305.0            NaN
# 3480    2.00          NaN  ...      2013.0           178.0            NaN
# 3481    2.00          NaN  ...      1975.0           123.0            NaN
# 3489    2.00          NaN  ...      2004.0           691.0            NaN
# 3548    2.00          NaN  ...      1972.0           648.0            NaN
# 3699    1.00          NaN  ...      1965.0           149.0            NaN
# 3700    2.00          NaN  ...      1974.0           145.0            NaN
# 3707    1.00          NaN  ...      1982.0            68.0            NaN
# 3726    2.00          NaN  ...      1996.0           451.0            NaN
# 3728    1.00          NaN  ...         NaN           488.0            NaN
# 3731    2.00          NaN  ...      1972.0           449.0            NaN
# 3745    2.00          NaN  ...      1973.0           162.0            NaN
# 5709    4.00          NaN  ...      2019.0            82.0            NaN
# 5859    2.00          NaN  ...      1940.0           131.0            NaN
# 6579    1.00          NaN  ...      2000.0           150.0            NaN
# 8989   16.00          NaN  ...      1955.0           579.0            NaN
# 11134   1.00          NaN  ...      1971.0           390.0            NaN
# 11258   2.00          NaN  ...      1978.0           526.0            NaN
# 11381   2.00          NaN  ...      1943.0           135.0            NaN
# 14492   2.00          NaN  ...      1983.0           359.0            NaN
# 14530   2.00          NaN  ...      1974.0           420.0            NaN
# 16056   2.00          NaN  ...      1976.0            29.0            NaN
# 16117   1.00          NaN  ...      1967.0           659.0            NaN
# 16124   1.00          NaN  ...      1969.0           580.0            NaN
# 16126   1.75          NaN  ...      1990.0           646.0            NaN
# 16127   1.00          NaN  ...      1957.0           274.0            NaN
# 16807   2.00          NaN  ...      1974.0           491.0            NaN
# 16813   1.00          NaN  ...      1967.0           659.0            NaN
# 16817   1.00          NaN  ...      1969.0           580.0            NaN
# 16819   1.75          NaN  ...      1990.0           646.0            NaN
# 16820   1.00          NaN  ...      1957.0           274.0            NaN
# 16830   1.00          NaN  ...      1982.0            80.0            NaN
# 16864   1.00          NaN  ...      1969.0            23.0            NaN
# 16883   1.00          NaN  ...         NaN           500.0            NaN
# 16930   2.00          NaN  ...      1977.0            83.0            NaN
# 16963   2.00          NaN  ...      1981.0           455.0            NaN
# 16964   2.00          NaN  ...      2006.0           475.0            NaN
# 16974   1.75          NaN  ...      2007.0           462.0            NaN
# 16975   1.00          NaN  ...      1963.0           479.0            NaN
# 16977   2.00          NaN  ...      1960.0           195.0            NaN
# 16978   1.75          NaN  ...      2002.0           177.0            NaN
# 16993   1.00          NaN  ...      1967.0           611.0            NaN
# 16994   1.00          NaN  ...      1968.0           534.0            NaN
# 16995   1.00          NaN  ...      1974.0           496.0            NaN
# 16997   1.00          NaN  ...      1971.0           546.0            NaN
# 16999   1.00          NaN  ...      1977.0           562.0            NaN
# 17000   1.00          NaN  ...      1965.0           716.0            NaN
# 17001   1.00          NaN  ...      1970.0           722.0            NaN
# 17002   1.00          NaN  ...      1968.0           678.0            NaN
# 17003   1.75          NaN  ...      1964.0           708.0            NaN
# 17004   1.00          NaN  ...      1976.0           559.0            NaN
# 17005   1.50          NaN  ...      1971.0           710.0            NaN
# 17016   2.00          NaN  ...      1976.0            29.0            NaN
# 17042   2.00          NaN  ...      2000.0           646.0            NaN
# 17051   2.00          NaN  ...      2006.0           554.0            NaN
# 18050   2.00          NaN  ...      1959.0           601.0            NaN
#
#        HOA/MONTH        MLS#   LATITUDE   LONGITUDE  \
# 2342         NaN    21803605  33.834720 -118.295804
# 3398         NaN  PV18014851  33.797926 -118.324125
# 3459       730.0   18-402926  33.869340 -118.267047
# 3480         NaN  PV19055877  33.869201 -118.263954
# 3481         NaN  OC19190455  33.869201 -118.263954
# 3489         NaN  DW18005930  33.831092 -118.245470
# 3548         NaN   18-314280  33.800060 -118.294470
# 3699       550.0  PW19157430  33.832616 -118.284374
# 3700         NaN  CV19154513  33.838516 -118.266713
# 3707         NaN  OC19235767  33.828448 -118.288134
# 3726         NaN  DW18178443  33.837421 -118.272515
# 3728       895.0   18-343458  33.821781 -118.297811
# 3731      1000.0  SB18240360  33.800090 -118.294537
# 3745         NaN  SB19162537  33.800090 -118.294537
# 5709       185.0   19-446904  33.878597 -118.299295
# 5859         NaN    21905072  33.960182 -118.360188
# 6579         NaN  SB19177315  33.877184 -118.309415
# 8989         NaN  RS18001633  33.947687 -118.327046
# 11134      826.0  RS18212204  33.782220 -118.279066
# 11258        NaN  IV18184518  33.782220 -118.279066
# 11381        NaN   19-483520  33.963142 -118.389632
# 14492        NaN  SB18285603  33.723242 -118.329708
# 14530        NaN  SB18239344  33.723262 -118.329780
# 16056        NaN  SB19240616  33.860345 -118.353828
# 16117        NaN  SB18032920  33.860345 -118.353828
# 16124        NaN  SB18078119  33.859199 -118.368294
# 16126        NaN  SB17192397  33.859199 -118.368294
# 16127        NaN  SB19041162  33.859212 -118.368279
# 16807        NaN  DW18161333  33.809912 -118.310239
# 16813        NaN  SB18032920  33.860345 -118.353828
# 16817        NaN  SB18078119  33.859199 -118.368294
# 16819        NaN  SB17192397  33.859199 -118.368294
# 16820        NaN  SB19041162  33.859212 -118.368279
# 16830        NaN  OC19235767  33.828448 -118.288134
# 16864        NaN  SB19261999  33.843181 -118.357473
# 16883      895.0   18-343458  33.821781 -118.297811
# 16930        NaN  SB19223126  33.788727 -118.329848
# 16963        NaN  SB18196895  33.809912 -118.310239
# 16964        NaN  DW18222014  33.809912 -118.310239
# 16974        NaN  SB18216302  33.841804 -118.355350
# 16975        NaN  SB18195238  33.843007 -118.355375
# 16977        NaN  IN19132701  33.842909 -118.355434
# 16978        NaN  SB19131428  33.843522 -118.354886
# 16993        NaN  SB18067906  33.843189 -118.357473
# 16994        NaN  SB18153282  33.843181 -118.357472
# 16995        NaN  SB18206698  33.843181 -118.357472
# 16997        NaN  SB18105473  33.843181 -118.357473
# 16999        NaN  SB18042640  33.843181 -118.357472
# 17000        NaN  SB18012890  33.843189 -118.357473
# 17001        NaN  SB18012869  33.843189 -118.357473
# 17002        NaN  SB17281239  33.843189 -118.357473
# 17003        NaN  SB17277571  33.843189 -118.357473
# 17004        NaN  SB18107368  33.843189 -118.357473
# 17005        NaN  SB18005670  33.843189 -118.357473
# 17016        NaN  SB19240616  33.860345 -118.353828
# 17042        NaN  SB18060804  33.809912 -118.310239
# 17051        NaN  DW18142176  33.809912 -118.310239
# 18050        NaN    21803605  33.834720 -118.295804
#
#                                       FILENAME COLLECTION   NEIGHBORHOOD
# 2342                carson_sfh_550_to_600K.csv          1         Carson
# 3398                       lomita_01_nosfh.csv          1         Lomita
# 3459                  carson_nosfh_nocondo.csv          1         Carson
# 3480                  carson_nosfh_nocondo.csv          1         Carson
# 3481                  carson_nosfh_nocondo.csv          1         Carson
# 3489                  carson_nosfh_nocondo.csv          1         Carson
# 3548                  carson_nosfh_nocondo.csv          1         Carson
# 3699                  carson_nosfh_nocondo.csv          1         Carson
# 3700                  carson_nosfh_nocondo.csv          1         Carson
# 3707                  carson_nosfh_nocondo.csv          1         Carson
# 3726                  carson_nosfh_nocondo.csv          1         Carson
# 3728                  carson_nosfh_nocondo.csv          1         Carson
# 3731                  carson_nosfh_nocondo.csv          1         Carson
# 3745                  carson_nosfh_nocondo.csv          1         Carson
# 5709     gardena_sfh_south_of_red_bch_blvd.csv          1        Gardena
# 5859               inglewood_04_sfh_3_beds.csv          1      Inglewood
# 6579              gardena_01_nosfh_nocondo.csv          1        Gardena
# 8989            inglewood_01_noSFH_nocondo.csv          1      Inglewood
# 11134               wilmington_0_to_3_beds.csv          1     Wilmington
# 11258               wilmington_0_to_3_beds.csv          1     Wilmington
# 11381       westchester_02_SFH_0_to_3_beds.csv          1    Westchester
# 14492  san-pedro_nosfh-nocondo-notownhouse.csv          2      San Pedro
# 14530  san-pedro_nosfh-nocondo-notownhouse.csv          2      San Pedro
# 16056     redondo_nosfh_nocondo_notownhome.csv          2  Redondo Beach
# 16117     redondo_nosfh_nocondo_notownhome.csv          2  Redondo Beach
# 16124     redondo_nosfh_nocondo_notownhome.csv          2  Redondo Beach
# 16126     redondo_nosfh_nocondo_notownhome.csv          2  Redondo Beach
# 16127     redondo_nosfh_nocondo_notownhome.csv          2  Redondo Beach
# 16807    torrance_nosfh-notownhome-nocondo.csv          2       Torrance
# 16813    torrance_nosfh-notownhome-nocondo.csv          2       Torrance
# 16817    torrance_nosfh-notownhome-nocondo.csv          2       Torrance
# 16819    torrance_nosfh-notownhome-nocondo.csv          2       Torrance
# 16820    torrance_nosfh-notownhome-nocondo.csv          2       Torrance
# 16830    torrance_nosfh-notownhome-nocondo.csv          2       Torrance
# 16864    torrance_nosfh-notownhome-nocondo.csv          2       Torrance
# 16883    torrance_nosfh-notownhome-nocondo.csv          2       Torrance
# 16930    torrance_nosfh-notownhome-nocondo.csv          2       Torrance
# 16963    torrance_nosfh-notownhome-nocondo.csv          2       Torrance
# 16964    torrance_nosfh-notownhome-nocondo.csv          2       Torrance
# 16974    torrance_nosfh-notownhome-nocondo.csv          2       Torrance
# 16975    torrance_nosfh-notownhome-nocondo.csv          2       Torrance
# 16977    torrance_nosfh-notownhome-nocondo.csv          2       Torrance
# 16978    torrance_nosfh-notownhome-nocondo.csv          2       Torrance
# 16993    torrance_nosfh-notownhome-nocondo.csv          2       Torrance
# 16994    torrance_nosfh-notownhome-nocondo.csv          2       Torrance
# 16995    torrance_nosfh-notownhome-nocondo.csv          2       Torrance
# 16997    torrance_nosfh-notownhome-nocondo.csv          2       Torrance
# 16999    torrance_nosfh-notownhome-nocondo.csv          2       Torrance
# 17000    torrance_nosfh-notownhome-nocondo.csv          2       Torrance
# 17001    torrance_nosfh-notownhome-nocondo.csv          2       Torrance
# 17002    torrance_nosfh-notownhome-nocondo.csv          2       Torrance
# 17003    torrance_nosfh-notownhome-nocondo.csv          2       Torrance
# 17004    torrance_nosfh-notownhome-nocondo.csv          2       Torrance
# 17005    torrance_nosfh-notownhome-nocondo.csv          2       Torrance
# 17016    torrance_nosfh-notownhome-nocondo.csv          2       Torrance
# 17042    torrance_nosfh-notownhome-nocondo.csv          2       Torrance
# 17051    torrance_nosfh-notownhome-nocondo.csv          2       Torrance
# 18050             torrance_sfh-5-plus-beds.csv          2       Torrance
#
# [58 rows x 21 columns]

# %%
# view empty square feet column by property type
south_bay[south_bay['SQUARE FEET'].isnull()].groupby(['PROPERTY TYPE'])['SOLD DATE'].count()
# Out:
# PROPERTY TYPE
# Mobile/Manufactured Home     52
# Single Family Residential     5
# Townhouse                     1
# Name: SOLD DATE, dtype: int64

# %%
# view properties with null square feet and are not mobile homes 
null_sqf = south_bay[(south_bay['SQUARE FEET'].isnull()) & (south_bay['PROPERTY TYPE'] != 'Mobile/Manufactured Home')]
null_sqf
# Out:
#        SOLD DATE              PROPERTY TYPE              ADDRESS         CITY  \
# 2342  2018-06-15  Single Family Residential     1132 Levinson St  Los Angeles
# 5709  2019-11-04  Single Family Residential  16908 Normandie Ave      Gardena
# 5859  2019-09-13  Single Family Residential       312 W Olive St  Los Angeles
# 8989  2018-06-22                  Townhouse   9725 Crenshaw Blvd    Inglewood
# 11381 2019-09-09  Single Family Residential       6015 W 83Rd Pl  Los Angeles
# 18050 2018-06-15  Single Family Residential     1132 Levinson St  Los Angeles
#
#       STATE OR PROVINCE  ZIP OR POSTAL CODE    PRICE  BEDS  BATHS  \
# 2342                 CA             90502.0   557000   5.0    2.0
# 5709                 CA             90247.0   800000   5.0    4.0
# 5859                 CA             90301.0   610000   3.0    2.0
# 8989                 CA             90305.0  1299999  32.0   16.0
# 11381                CA             90045.0  1038487   3.0    2.0
# 18050                CA             90502.0   557000   5.0    2.0
#
#        SQUARE FEET  ...  YEAR BUILT  DAYS ON MARKET  $/SQUARE FEET  HOA/MONTH  \
# 2342           NaN  ...      1959.0           589.0            NaN        NaN
# 5709           NaN  ...      2019.0            82.0            NaN      185.0
# 5859           NaN  ...      1940.0           131.0            NaN        NaN
# 8989           NaN  ...      1955.0           579.0            NaN        NaN
# 11381          NaN  ...      1943.0           135.0            NaN        NaN
# 18050          NaN  ...      1959.0           601.0            NaN        NaN
#
#              MLS#   LATITUDE   LONGITUDE  \
# 2342     21803605  33.834720 -118.295804
# 5709    19-446904  33.878597 -118.299295
# 5859     21905072  33.960182 -118.360188
# 8989   RS18001633  33.947687 -118.327046
# 11381   19-483520  33.963142 -118.389632
# 18050    21803605  33.834720 -118.295804
#
#                                     FILENAME COLLECTION NEIGHBORHOOD
# 2342              carson_sfh_550_to_600K.csv          1       Carson
# 5709   gardena_sfh_south_of_red_bch_blvd.csv          1      Gardena
# 5859             inglewood_04_sfh_3_beds.csv          1    Inglewood
# 8989          inglewood_01_noSFH_nocondo.csv          1    Inglewood
# 11381     westchester_02_SFH_0_to_3_beds.csv          1  Westchester
# 18050           torrance_sfh-5-plus-beds.csv          2     Torrance
#
# [6 rows x 21 columns]

# %%
# drop rows
south_bay.drop(null_sqf.index,inplace=True)

# %%
# view square feet for mobile homes that are not null
south_bay[~(south_bay['SQUARE FEET'].isnull()) & (south_bay['PROPERTY TYPE'] == 'Mobile/Manufactured Home')].head()
# Out:
#       SOLD DATE             PROPERTY TYPE                       ADDRESS  \
# 3234 2019-06-14  Mobile/Manufactured Home          2436 Lomita Blvd #19
# 3251 2019-08-09  Mobile/Manufactured Home              24200 Walnut #10
# 3254 2019-02-07  Mobile/Manufactured Home  24100 S Pennsylvania Ave #92
# 3300 2019-12-20  Mobile/Manufactured Home              24200 Walnut #29
# 3301 2020-01-08  Mobile/Manufactured Home           24200 Walnut St #53
#
#           CITY STATE OR PROVINCE  ZIP OR POSTAL CODE   PRICE  BEDS  BATHS  \
# 3234    Lomita                CA             90717.0   69500   2.0   1.50
# 3251  Torrance                CA             90501.0  170000   3.0   2.00
# 3254    Lomita                CA             90717.0  250000   2.0   1.75
# 3300  Torrance                CA             90501.0   25000   2.0   2.00
# 3301  Torrance                CA             90501.0   13000   1.0   1.00
#
#       SQUARE FEET  ...  YEAR BUILT  DAYS ON MARKET  $/SQUARE FEET  HOA/MONTH  \
# 3234        800.0  ...      1973.0           225.0           87.0        NaN
# 3251       1620.0  ...      2002.0           169.0          105.0        NaN
# 3254       1040.0  ...      2005.0           352.0          240.0        NaN
# 3300       1040.0  ...      1977.0            36.0           24.0        NaN
# 3301        448.0  ...      1963.0            17.0           29.0        NaN
#
#             MLS#   LATITUDE   LONGITUDE             FILENAME COLLECTION  \
# 3234  SB18282786  33.804584 -118.326531  lomita_01_nosfh.csv          1
# 3251  SB19088581  33.806212 -118.310937  lomita_01_nosfh.csv          1
# 3254  SB18194443  33.805923 -118.325014  lomita_01_nosfh.csv          1
# 3300  CV19262840  33.806188 -118.310948  lomita_01_nosfh.csv          1
# 3301  CV19262056  33.806188 -118.310948  lomita_01_nosfh.csv          1
#
#      NEIGHBORHOOD
# 3234       Lomita
# 3251       Lomita
# 3254       Lomita
# 3300       Lomita
# 3301       Lomita
#
# [5 rows x 21 columns]

# %%
# fill mobile home square feet with average sq feet

# find average sq feet for mobile homes
mh_means = south_bay[south_bay['PROPERTY TYPE'] == 'Mobile/Manufactured Home'].mean(axis=0,skipna=True)

# get mean for square feet
mh_sqft_mean = mh_means['SQUARE FEET']


# fill na with mean
south_bay['SQUARE FEET'].fillna(mh_sqft_mean,inplace=True)

# %%
# view Square Feet of 0
south_bay[south_bay['SQUARE FEET'] == 0]
# Out:
#        SOLD DATE              PROPERTY TYPE           ADDRESS           CITY  \
# 5204  2018-12-13  Single Family Residential     2302 Ozone Ct  Hermosa Beach
# 11373 2018-06-27  Single Family Residential  8323 Gonzaga Ave    Los Angeles
# 19506 2018-03-01  Single Family Residential    19507 Anza Ave       Torrance
#
#       STATE OR PROVINCE  ZIP OR POSTAL CODE    PRICE  BEDS  BATHS  \
# 5204                 CA             90254.0   919000   2.0    2.0
# 11373                CA             90045.0  1200000   3.0    2.0
# 19506                CA             90503.0   935000   1.0    1.0
#
#        SQUARE FEET  ...  YEAR BUILT  DAYS ON MARKET  $/SQUARE FEET  HOA/MONTH  \
# 5204           0.0  ...      1925.0           408.0            NaN        NaN
# 11373          0.0  ...      1938.0           574.0            NaN        NaN
# 19506          0.0  ...      1974.0           707.0            NaN        NaN
#
#              MLS#   LATITUDE   LONGITUDE                            FILENAME  \
# 5204   SB18268749  33.870561 -118.402754               hermosa-beach_sfh.csv
# 11373   18-344092  33.962519 -118.418026  westchester_02_SFH_0_to_3_beds.csv
# 19506  PV18015102  33.853255 -118.363681           torrance_sfh-0-2-beds.csv
#
#       COLLECTION   NEIGHBORHOOD
# 5204           1  Hermosa Beach
# 11373          1    Westchester
# 19506          2       Torrance
#
# [3 rows x 21 columns]

# %%
# update property at 19507 Anza Ave: square feet 1762
south_bay.at[17234, 'SQUARE FEET'] = 1762

# %%
#drop other two properties
south_bay.drop(south_bay[south_bay['SQUARE FEET'] == 0].index, axis=0, inplace=True)

# %% [markdown]
# LOT SIZE:

# %%
# view length of empty data for LOT SIZE column 
len(south_bay[south_bay['LOT SIZE'].isnull()])
# Out:
# 555

# %%
# view empty lot size by property type
south_bay[south_bay['LOT SIZE'].isnull()].groupby(['PROPERTY TYPE'])['SOLD DATE'].count()
# Out:
# PROPERTY TYPE
# Condo/Co-op                  118
# Mobile/Manufactured Home     309
# Single Family Residential     12
# Townhouse                    116
# Name: SOLD DATE, dtype: int64

# %%
# create list of property types
prop_type = ['Condo/Co-op', 'Mobile/Manufactured Home', 'Single Family Residential', 'Townhouse']

#create list of columns to display
cols_list = ['PROPERTY TYPE','PRICE','BEDS','BATHS','SQUARE FEET','LOT SIZE','YEAR BUILT', \
             'DAYS ON MARKET', '$/SQUARE FEET']

# %% [markdown]
# - Condo/Co-op

# %%
# look at Condo/Co-op lots
condos = south_bay[south_bay['PROPERTY TYPE'] == prop_type[0]]
condos[cols_list].head(10)
# Out:
#     PROPERTY TYPE   PRICE  BEDS  BATHS  SQUARE FEET  LOT SIZE  YEAR BUILT  \
# 415   Condo/Co-op  540000   3.0    2.0       1190.0  102784.0      1968.0
# 416   Condo/Co-op  465000   2.0    2.0        905.0  102784.0      1968.0
# 421   Condo/Co-op  540000   3.0    2.0       1167.0  102539.0      1968.0
# 422   Condo/Co-op  363500   1.0    1.0        695.0  102539.0      1968.0
# 423   Condo/Co-op  454000   2.0    2.0        873.0  102539.0      1968.0
# 424   Condo/Co-op  508500   2.0    2.0       1114.0  102539.0      1968.0
# 425   Condo/Co-op  449000   2.0    2.0        873.0  102539.0      1968.0
# 427   Condo/Co-op  829000   4.0    4.0       1595.0   66543.0      2007.0
# 429   Condo/Co-op  349000   1.0    1.0        595.0  102539.0      1968.0
# 430   Condo/Co-op  505000   2.0    2.0        929.0  102784.0      1968.0
#
#      DAYS ON MARKET  $/SQUARE FEET
# 415           558.0          454.0
# 416           208.0          514.0
# 421           194.0          463.0
# 422           149.0          523.0
# 423           131.0          520.0
# 424           117.0          456.0
# 425            90.0          514.0
# 427            49.0          520.0
# 429           301.0          587.0
# 430           409.0          544.0

# %%
condos['LOT SIZE'].describe()
# Out:
# count    2.489000e+03
# mean     1.160418e+06
# std      3.152981e+07
# min      4.000000e+00
# 25%      2.472400e+04
# 50%      6.525400e+04
# 75%      1.769820e+05
# max      1.148808e+09
# Name: LOT SIZE, dtype: float64

# %% [markdown]
# - Mobile/Manufactured Homes

# %%
# look at Mobile Homes lots missing data
mobile = south_bay[(south_bay['PROPERTY TYPE'] == prop_type[1]) & (~south_bay['LOT SIZE'].isnull())]
mobile[cols_list].head(10)
# Out:
#                  PROPERTY TYPE   PRICE  BEDS  BATHS  SQUARE FEET   LOT SIZE  \
# 3324  Mobile/Manufactured Home  165000   2.0   2.00        800.0    80889.0
# 3327  Mobile/Manufactured Home   70000   2.0   1.00        800.0    58237.0
# 3391  Mobile/Manufactured Home   73000   3.0   2.00       1200.0   268225.0
# 3448  Mobile/Manufactured Home  109900   2.0   2.00        944.0    44256.0
# 3455  Mobile/Manufactured Home  178000   2.0   1.75       1000.0     2257.0
# 3458  Mobile/Manufactured Home  183500   2.0   1.75       1784.0  3113589.0
# 3478  Mobile/Manufactured Home  139000   2.0   2.00       1400.0     3000.0
# 3498  Mobile/Manufactured Home  230000   3.0   2.00       1231.0     2400.0
# 3503  Mobile/Manufactured Home  173000   2.0   2.00       1200.0    72791.0
# 3519  Mobile/Manufactured Home  192000   2.0   2.00       1250.0  2284648.0
#
#       YEAR BUILT  DAYS ON MARKET  $/SQUARE FEET
# 3324      2013.0           180.0          206.0
# 3327      1955.0           715.0           88.0
# 3391      2003.0           267.0           61.0
# 3448      2005.0           318.0          116.0
# 3455      1991.0           149.0          178.0
# 3458      1979.0           339.0          103.0
# 3478      1979.0           227.0           99.0
# 3498      2005.0           712.0          187.0
# 3503      1976.0           367.0          144.0
# 3519      2007.0           486.0          154.0

# %%
mobile['LOT SIZE'].describe()
# Out:
# count    4.000000e+01
# mean     4.867528e+05
# std      8.588946e+05
# min      1.302000e+03
# 25%      3.737500e+03
# 50%      7.980150e+04
# 75%      3.696890e+05
# max      3.113589e+06
# Name: LOT SIZE, dtype: float64

# %% [markdown]
# - Single Family Residential

# %%
# look at Single Family Residential lots
sfr = south_bay[south_bay['PROPERTY TYPE'] == prop_type[2]]
sfr[cols_list].head(10)
# Out:
#                 PROPERTY TYPE   PRICE  BEDS  BATHS  SQUARE FEET  LOT SIZE  \
# 1   Single Family Residential  730000   7.0    5.0       3401.0    6651.0
# 9   Single Family Residential  547000   4.0    2.0       1948.0    5399.0
# 10  Single Family Residential  774000   5.0    3.5       2900.0    5857.0
# 14  Single Family Residential  537500   4.0    2.0       1431.0    5238.0
# 15  Single Family Residential  525000   4.0    3.0       1312.0    6246.0
# 17  Single Family Residential  515000   5.0    2.0       1822.0    6701.0
# 22  Single Family Residential  480000   4.0    2.0       1245.0    4800.0
# 23  Single Family Residential  500000   4.0    2.0       1476.0    4806.0
# 25  Single Family Residential  490000   4.0    2.0       1589.0    4806.0
# 26  Single Family Residential  485000   4.0    2.0       1595.0    5570.0
#
#     YEAR BUILT  DAYS ON MARKET  $/SQUARE FEET
# 1       2008.0           358.0          215.0
# 9       1962.0           604.0          281.0
# 10      1940.0            86.0          267.0
# 14      1953.0           312.0          376.0
# 15      1913.0           246.0          400.0
# 17      1905.0           128.0          283.0
# 22      1952.0             2.0          386.0
# 23      1950.0           243.0          339.0
# 25      1948.0            30.0          308.0
# 26      1962.0           333.0          304.0

# %%
sfr['LOT SIZE'].describe()
# Out:
# count    9.913000e+03
# mean     8.636242e+04
# std      4.021049e+06
# min      6.500000e+02
# 25%      5.074000e+03
# 50%      5.825000e+03
# 75%      7.206000e+03
# max      2.426292e+08
# Name: LOT SIZE, dtype: float64

# %% [markdown]
# - Townhome

# %%
# look at Townhome lots
townhome = south_bay[south_bay['PROPERTY TYPE'] == prop_type[3]]
townhome[cols_list].head(10)
# Out:
#     PROPERTY TYPE   PRICE  BEDS  BATHS  SQUARE FEET  LOT SIZE  YEAR BUILT  \
# 12      Townhouse  619900   4.0    2.0       1332.0    6605.0      1941.0
# 13      Townhouse  460000   5.0    4.0       1700.0    6402.0      1926.0
# 24      Townhouse  468000   4.0    3.0       1434.0    4816.0      1924.0
# 38      Townhouse  455000   4.0    2.0       1642.0    5205.0      1923.0
# 51      Townhouse  485000   4.0    2.0       1470.0    5020.0      1922.0
# 54      Townhouse  550000   4.0    4.0       2600.0    5999.0      1911.0
# 70      Townhouse  440000   4.0    2.0       1340.0    4759.0      1928.0
# 94      Townhouse  569000   4.0    3.0       1960.0    7514.0      1927.0
# 419     Townhouse  695000   3.0    3.0       1374.0   66632.0      2007.0
# 432     Townhouse  925000   4.0    2.0       1612.0    6704.0      1948.0
#
#      DAYS ON MARKET  $/SQUARE FEET
# 12            285.0          465.0
# 13            712.0          271.0
# 24            393.0          326.0
# 38            565.0          277.0
# 51            527.0          330.0
# 54            437.0          212.0
# 70            584.0          328.0
# 94            491.0          290.0
# 419           645.0          506.0
# 432           651.0          574.0

# %%
townhome['LOT SIZE'].describe()
# Out:
# count    2.485000e+03
# mean     7.945422e+05
# std      2.002350e+07
# min      1.000000e+02
# 25%      6.465000e+03
# 50%      1.201900e+04
# 75%      5.873000e+04
# max      6.758334e+08
# Name: LOT SIZE, dtype: float64

# %% [markdown]
# - Fill NA

# %%
# fill NAs with median value for each property type

south_bay['LOT SIZE'] = south_bay.groupby(['PROPERTY TYPE'])['LOT SIZE'].apply(lambda x: x.fillna(x.median()))

# %% [markdown]
# YEAR BUILT:

# %%
# find empty years
no_year = south_bay[south_bay['YEAR BUILT'].isnull()]
no_year.to_csv('../data/interim/no year.csv')

# %%
# drop empty years
south_bay.dropna(subset=['YEAR BUILT'], axis=0, inplace=True)

# %%
# check for year built outside of 1818 to 2020 range
year_check = (south_bay['YEAR BUILT'] < 1818) | (south_bay['YEAR BUILT'] > 2020)
print(south_bay.loc[:,['SOLD DATE', 'ADDRESS', 'PROPERTY TYPE', 'YEAR BUILT','FILENAME']][year_check])
# Out:
#       SOLD DATE             ADDRESS              PROPERTY TYPE  YEAR BUILT  \
# 5373 2019-11-06  701 Longfellow Ave  Single Family Residential      2021.0
# 7246 2019-11-06  701 Longfellow Ave  Single Family Residential      2021.0
#
#                           FILENAME
# 5373         hermosa-beach_sfh.csv
# 7246  manhattan-beach_2.5M_max.csv

# %%
# drop property built in 2021
south_bay.drop(index=[5744,7925],inplace=True)

# %% [markdown]
# $/SQUARE FEET:

# %%
# pull empty data about $/SQUARE FEET
ppsqf_nulls = south_bay[south_bay['$/SQUARE FEET'].isnull()]

# %%
# create formula to fill $/SQUARE FEET
ppsqf_fill = south_bay['PRICE'] / south_bay['SQUARE FEET']

# %%
# fill na with ppsqf results
south_bay['$/SQUARE FEET'].fillna(ppsqf_fill, inplace=True)

# %% [markdown]
# HOA/MONTH:

# %%
# view empty data for HOA/MONTH column 
south_bay[south_bay['HOA/MONTH'].isnull()]
# Out:
#        SOLD DATE              PROPERTY TYPE             ADDRESS        CITY  \
# 1     2019-02-01  Single Family Residential   1641 Bay View Ave  Wilmington
# 9     2018-05-31  Single Family Residential  1410 W Sandison St  Wilmington
# 10    2019-10-31  Single Family Residential   1703 N Marine Ave  Wilmington
# 12    2019-04-15                  Townhouse  1702 N Neptune Ave  Wilmington
# 13    2018-02-12                  Townhouse     721 Pioneer Ave  Wilmington
# ...          ...                        ...                 ...         ...
# 19521 2018-11-09  Single Family Residential       2445 251St St      Lomita
# 19523 2019-12-13  Single Family Residential     3112 Winlock Rd    Torrance
# 19524 2018-10-19  Single Family Residential     18334 Falda Ave    Torrance
# 19525 2020-01-02  Single Family Residential    1615 Juniper Ave    Torrance
# 19526 2018-03-06  Single Family Residential     1419 Acacia Ave    Torrance
#
#       STATE OR PROVINCE  ZIP OR POSTAL CODE   PRICE  BEDS  BATHS  SQUARE FEET  \
# 1                    CA             90744.0  730000   7.0    5.0       3401.0
# 9                    CA             90744.0  547000   4.0    2.0       1948.0
# 10                   CA             90744.0  774000   5.0    3.5       2900.0
# 12                   CA             90744.0  619900   4.0    2.0       1332.0
# 13                   CA             90744.0  460000   5.0    4.0       1700.0
# ...                 ...                 ...     ...   ...    ...          ...
# 19521                CA             90717.0  800000   2.0    1.0       1030.0
# 19523                CA             90505.0  915000   3.0    2.0       1576.0
# 19524                CA             90504.0  573500   2.0    1.0        873.0
# 19525                CA             90503.0  839000   2.0    1.0       1230.0
# 19526                CA             90501.0  840000   2.0    1.5       1653.0
#
#        ...  YEAR BUILT  DAYS ON MARKET  $/SQUARE FEET  HOA/MONTH        MLS#  \
# 1      ...      2008.0           358.0          215.0        NaN  SB18278853
# 9      ...      1962.0           604.0          281.0        NaN  SB18091442
# 10     ...      1940.0            86.0          267.0        NaN  PW19223929
# 12     ...      1941.0           285.0          465.0        NaN  CV18258904
# 13     ...      1926.0           712.0          271.0        NaN  DW18004410
# ...    ...         ...             ...            ...        ...         ...
# 19521  ...      1915.0           454.0          777.0        NaN   18-387308
# 19523  ...      1950.0            55.0          581.0        NaN   19-519406
# 19524  ...      1953.0           475.0          657.0        NaN   18-362202
# 19525  ...      1949.0            35.0          682.0        NaN  SB19261266
# 19526  ...      1938.0           702.0          508.0        NaN  SB18030101
#
#         LATITUDE   LONGITUDE                    FILENAME COLLECTION  \
# 1      33.796254 -118.271532  wilmington_4_plus_beds.csv          1
# 9      33.792195 -118.280823  wilmington_4_plus_beds.csv          1
# 10     33.797547 -118.265430  wilmington_4_plus_beds.csv          1
# 12     33.797256 -118.270032  wilmington_4_plus_beds.csv          1
# 13     33.779983 -118.248288  wilmington_4_plus_beds.csv          1
# ...          ...         ...                         ...        ...
# 19521  33.797001 -118.326949   torrance_sfh-0-2-beds.csv          2
# 19523  33.794174 -118.341834   torrance_sfh-0-2-beds.csv          2
# 19524  33.863952 -118.329735   torrance_sfh-0-2-beds.csv          2
# 19525  33.832390 -118.337177   torrance_sfh-0-2-beds.csv          2
# 19526  33.833828 -118.326584   torrance_sfh-0-2-beds.csv          2
#
#       NEIGHBORHOOD
# 1       Wilmington
# 9       Wilmington
# 10      Wilmington
# 12      Wilmington
# 13      Wilmington
# ...            ...
# 19521     Torrance
# 19523     Torrance
# 19524     Torrance
# 19525     Torrance
# 19526     Torrance
#
# [10105 rows x 21 columns]

# %%
#view HOA/MONTH column with 0 values
south_bay[south_bay['HOA/MONTH'] == 0]
# Out:
#        SOLD DATE              PROPERTY TYPE                   ADDRESS  \
# 3607  2018-11-02   Mobile/Manufactured Home  17701 S Avalon Blvd #334
# 9504  2019-10-29  Single Family Residential          31 Chuckwagon Rd
# 9508  2019-03-21  Single Family Residential            23 Georgeff Rd
# 9522  2019-08-27  Single Family Residential     70 Portuguese Bend Rd
# 9524  2019-10-21  Single Family Residential            8 Pine Tree Ln
# 9528  2018-04-12  Single Family Residential         2316 Via Carrillo
# 10821 2019-03-19  Single Family Residential            19 Buckskin Ln
#
#                         CITY STATE OR PROVINCE  ZIP OR POSTAL CODE    PRICE  \
# 3607                  Carson                CA             90746.0   295000
# 9504           Rolling Hills                CA             90274.0  2500000
# 9508           Rolling Hills                CA             90274.0  1990000
# 9522           Rolling Hills                CA             90274.0  1335000
# 9524           Rolling Hills                CA             90274.0  2725000
# 9528    Palos Verdes Estates                CA             90274.0  1675000
# 10821  Rolling Hills Estates                CA             90274.0  1900000
#
#        BEDS  BATHS  SQUARE FEET  ...  YEAR BUILT  DAYS ON MARKET  \
# 3607    3.0   2.00       1814.0  ...      1979.0           449.0
# 9504    4.0   3.00       3106.0  ...      1959.0            85.0
# 9508    3.0   2.50       2559.0  ...      1957.0           307.0
# 9522    4.0   3.00       3122.0  ...      1949.0           148.0
# 9524    3.0   2.25       2812.0  ...      1952.0            93.0
# 9528    4.0   3.00       2399.0  ...      1964.0           653.0
# 10821   4.0   2.00       2016.0  ...      1947.0           312.0
#
#        $/SQUARE FEET  HOA/MONTH        MLS#   LATITUDE   LONGITUDE  \
# 3607           163.0        0.0  SB18233065  33.869340 -118.267047
# 9504           805.0        0.0  PV19135556  33.761317 -118.339666
# 9508           778.0        0.0  PV18260415  33.759767 -118.344597
# 9522           428.0        0.0  PV17256560  33.747823 -118.351628
# 9524           969.0        0.0  PV18062471  33.767945 -118.348729
# 9528           698.0        0.0  PV18043994  33.775560 -118.414781
# 10821          942.0        0.0  PV18287807  33.773739 -118.332885
#
#                                    FILENAME COLLECTION           NEIGHBORHOOD
# 3607               carson_nosfh_nocondo.csv          1                 Carson
# 9504                      rolling-hills.csv          1          Rolling Hills
# 9508                      rolling-hills.csv          1          Rolling Hills
# 9522                      rolling-hills.csv          1          Rolling Hills
# 9524                      rolling-hills.csv          1          Rolling Hills
# 9528   palos-verdes-estates_4_plus_beds.csv          1   Palos Verdes Estates
# 10821      rolling-hills-estates_01_sfh.csv          1  Rolling Hills Estates
#
# [7 rows x 21 columns]

# %%
# fill NA HOA/MONTH values with 0 
south_bay['HOA/MONTH'].fillna(value=0, inplace=True)

# %% [markdown]
# #### DUPLICATE VALUES

# %% [markdown]
# - We'll first check for duplicates on all columns but the newly created ones

# %%
# create subset columns to check for duplicates 
subset_cols = ['SOLD DATE', 'PROPERTY TYPE', 'ADDRESS', 'CITY', 'STATE OR PROVINCE',\
               'ZIP OR POSTAL CODE', 'PRICE', 'BEDS', 'BATHS', 'SQUARE FEET',\
               'LOT SIZE', 'YEAR BUILT', 'DAYS ON MARKET', '$/SQUARE FEET',\
               'HOA/MONTH', 'LATITUDE', 'LONGITUDE']

# %%
# display duplicates and save to file to inspect
sb_dupes = south_bay[south_bay.duplicated(subset=subset_cols , keep=False)]
sb_dupes = sb_dupes.sort_values(by=['ADDRESS'])
sb_dupes.to_csv('../data/interim/sb_dupes1.csv')

# %%
# create subset with duplicated values & update neighborhood value with name of city
dupe_bool = south_bay.duplicated(subset = subset_cols, keep=False)
south_bay.loc[dupe_bool,'NEIGHBORHOOD'] = south_bay['CITY']

# %%
# verify one address from original duplicate file to check neighborhood change
south_bay[south_bay['ADDRESS'] == '10019 S Burl Ave Unit N']
# Out:
#       SOLD DATE              PROPERTY TYPE                  ADDRESS  \
# 1024 2018-09-21  Single Family Residential  10019 S Burl Ave Unit N
# 5024 2018-09-21  Single Family Residential  10019 S Burl Ave Unit N
#
#            CITY STATE OR PROVINCE  ZIP OR POSTAL CODE   PRICE  BEDS  BATHS  \
# 1024  Inglewood                CA             90304.0  530000   2.0    1.0
# 5024  Inglewood                CA             90304.0  530000   2.0    1.0
#
#       SQUARE FEET  ...  YEAR BUILT  DAYS ON MARKET  $/SQUARE FEET  HOA/MONTH  \
# 1024        832.0  ...      1942.0           488.0          637.0        0.0
# 5024        832.0  ...      1942.0           488.0          637.0        0.0
#
#            MLS#   LATITUDE   LONGITUDE                             FILENAME  \
# 1024  218010629  33.944791 -118.362654  inglewood_03_sfh_2_beds_or_less.csv
# 5024  218010629  33.944791 -118.362654                           lennox.csv
#
#      COLLECTION NEIGHBORHOOD
# 1024          1    Inglewood
# 5024          1    Inglewood
#
# [2 rows x 21 columns]

# %%
# drop duplicates
south_bay.drop_duplicates(subset=subset_cols,keep='first',inplace=True)

# %% [markdown]
# - Next, we'll look for duplicates based on MLS#. The MLS# should be a unique value.

# %%
# look at MLS# duplicates
sb_dupes2 = south_bay[south_bay.duplicated(subset= 'MLS#', keep=False)]
sb_dupes2.sort_values(by=['ADDRESS']).to_csv('../data/interim/sb_dupes2.csv')

# %% [markdown]
# Upon inspecting the CSV output, the values that seem to differ between the duplicate rows are the neighborhood and the days on market column. We will use the max value for days on market, and update the neighborhood values as before - and drop the others rows.

# %%
# create subset with duplicated values & update neighborhood value as before
dupe_bool = south_bay.duplicated(subset = 'MLS#', keep=False)
south_bay.loc[dupe_bool,'NEIGHBORHOOD'] = south_bay['CITY']

# %%
# sort values then drop duplicates
south_bay.sort_values(['ADDRESS','DAYS ON MARKET'])
south_bay.drop_duplicates('MLS#', keep='last', inplace=True)

# %%
# verify one address from original MLS duplicate file to see Days on Market change
# days on market should be 608
south_bay[south_bay['ADDRESS'] == '1001 Park Circle Dr']
# Out:
#        SOLD DATE PROPERTY TYPE              ADDRESS      CITY  \
# 11706 2018-06-08   Condo/Co-op  1001 Park Circle Dr  Torrance
#
#       STATE OR PROVINCE  ZIP OR POSTAL CODE   PRICE  BEDS  BATHS  SQUARE FEET  \
# 11706                CA             90502.0  570000   3.0    2.5       1624.0
#
#        ...  YEAR BUILT  DAYS ON MARKET  $/SQUARE FEET  HOA/MONTH        MLS#  \
# 11706  ...      1984.0           608.0          351.0      315.0  SB18086197
#
#         LATITUDE   LONGITUDE                       FILENAME COLLECTION  \
# 11706  33.814929 -118.293785  torrance_condos-500K_plus.csv          2
#
#       NEIGHBORHOOD
# 11706     Torrance
#
# [1 rows x 21 columns]

# %%
south_bay.drop_duplicates(subset=subset_cols,keep='first',inplace=True)

# %% [markdown]
# #### VARIABLE TYPES

# %%
# change variable types for: ZIP OR POSTAL CODE, YEAR BUILT
south_bay['ZIP OR POSTAL CODE'] = south_bay['ZIP OR POSTAL CODE'].astype(int)
south_bay['YEAR BUILT'] = south_bay['YEAR BUILT'].astype(int)

# %% [markdown]
# #### INSPECT FINAL DATA FRAME

# %%
# drop filename, state and collection column
south_bay.drop(['STATE OR PROVINCE','FILENAME','COLLECTION'], axis=1,inplace=True)

# %%
# reorder columns to move price to front and drop state and MLS# column *

cols = ['SOLD DATE', 'PROPERTY TYPE', 'ADDRESS', 'CITY', 'PRICE',
       'ZIP OR POSTAL CODE', 'BEDS', 'BATHS', 'SQUARE FEET',
       'LOT SIZE', 'YEAR BUILT', 'DAYS ON MARKET', '$/SQUARE FEET',
       'HOA/MONTH', 'MLS#', 'LATITUDE', 'LONGITUDE', 'NEIGHBORHOOD']

south_bay = south_bay[cols]

# %%
# reset index
south_bay = south_bay.reset_index(drop=True)

# %%
south_bay.head()
# Out:
#    SOLD DATE              PROPERTY TYPE             ADDRESS        CITY  \
# 0 2019-02-01  Single Family Residential   1641 Bay View Ave  Wilmington
# 1 2018-05-31  Single Family Residential  1410 W Sandison St  Wilmington
# 2 2019-10-31  Single Family Residential   1703 N Marine Ave  Wilmington
# 3 2019-04-15                  Townhouse  1702 N Neptune Ave  Wilmington
# 4 2018-02-12                  Townhouse     721 Pioneer Ave  Wilmington
#
#     PRICE  ZIP OR POSTAL CODE  BEDS  BATHS  SQUARE FEET  LOT SIZE  YEAR BUILT  \
# 0  730000               90744   7.0    5.0       3401.0    6651.0        2008
# 1  547000               90744   4.0    2.0       1948.0    5399.0        1962
# 2  774000               90744   5.0    3.5       2900.0    5857.0        1940
# 3  619900               90744   4.0    2.0       1332.0    6605.0        1941
# 4  460000               90744   5.0    4.0       1700.0    6402.0        1926
#
#    DAYS ON MARKET  $/SQUARE FEET  HOA/MONTH        MLS#   LATITUDE  \
# 0           358.0          215.0        0.0  SB18278853  33.796254
# 1           604.0          281.0        0.0  SB18091442  33.792195
# 2            86.0          267.0        0.0  PW19223929  33.797547
# 3           285.0          465.0        0.0  CV18258904  33.797256
# 4           712.0          271.0        0.0  DW18004410  33.779983
#
#     LONGITUDE NEIGHBORHOOD
# 0 -118.271532   Wilmington
# 1 -118.280823   Wilmington
# 2 -118.265430   Wilmington
# 3 -118.270032   Wilmington
# 4 -118.248288   Wilmington

# %%
south_bay.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13631 entries, 0 to 13630
# Data columns (total 18 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   SOLD DATE           13631 non-null  datetime64[ns]
#  1   PROPERTY TYPE       13631 non-null  object
#  2   ADDRESS             13631 non-null  object
#  3   CITY                13631 non-null  object
#  4   PRICE               13631 non-null  int64
#  5   ZIP OR POSTAL CODE  13631 non-null  int64
#  6   BEDS                13631 non-null  float64
#  7   BATHS               13631 non-null  float64
#  8   SQUARE FEET         13631 non-null  float64
#  9   LOT SIZE            13631 non-null  float64
#  10  YEAR BUILT          13631 non-null  int64
#  11  DAYS ON MARKET      13631 non-null  float64
#  12  $/SQUARE FEET       13631 non-null  float64
#  13  HOA/MONTH           13631 non-null  float64
#  14  MLS#                13631 non-null  object
#  15  LATITUDE            13631 non-null  float64
#  16  LONGITUDE           13631 non-null  float64
#  17  NEIGHBORHOOD        13631 non-null  object
# dtypes: datetime64[ns](1), float64(9), int64(3), object(5)
# memory usage: 1.9+ MB

# %%
south_bay.to_csv('../data/processed/south_bay_cleaned.csv', index=False)
